# %%
from datetime import datetime
import pytz

def fecha_hora_lima():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y%m%d-%H%M%S')

def fecha_hora_lima_db():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y-%m-%d %H:%M:%S')

fecha_hora_para_archivos = fecha_hora_lima()
fecha_hora_para_base_de_datos = fecha_hora_lima_db()

# %%
import pandas as pd
import requests
import json

# URL del JSON
url = 'https://www.plazavea.com.pe/api/catalog_system/pub/category/tree/3'

# Solicitar el contenido JSON desde la URL
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    data = response.json()  # Convertir la respuesta en un objeto JSON
    file_name = f'categories_{fecha_hora_para_archivos}.json'
    
    # Guardar el JSON en un archivo
    with open(file_name, 'w') as file:
        json.dump(data, file, indent=4)

    print('El archivo JSON se ha guardado exitosamente.')
    with open(file_name, 'r') as file:
        data = json.load(file)
    print(len(data)) 
else:
    print(f'Error al obtener el JSON. Código de estado: {response.status_code}')
# Out:
# El archivo JSON se ha guardado exitosamente.
# 37

# %%
# file_path = 'plazavea_categories.json'
# 
# with open(file_path, 'r') as file:
#     data = json.load(file)
#     print(json.dumps(data, indent=4))

# %%
columns = ['id', 'name', 'hasChildren', 'url', 'NumChildren', 'Title', 'MetaTagDescription', 'parent_id']
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [id, name, hasChildren, url, NumChildren, Title, MetaTagDescription, parent_id]
# Index: []

# %%
for item in data:
  if item['hasChildren']:
    item['parent_id'] = ''
    item['NumChildren'] = len(item['children'])

    df.loc[len(df)] = item

    parent_id = item['id']

    for subitem in item['children']:
      subitem['parent_id'] = parent_id
      sub_parent_id = subitem['id']
      subitem['NumChildren'] = len(subitem['children'])

      df.loc[len(df)] = subitem

      if len(subitem['children']) > 0:
        for subsubitem in subitem['children']:
          subsubitem['parent_id'] = sub_parent_id
          subsubitem['NumChildren'] = len(subsubitem['children'])
          df.loc[len(df)] = subsubitem

# %%
df.query("id == 952")
# Out:
#     id         name  hasChildren  \
# 4  952  Agua Tónica        False
#
#                                                  url  NumChildren  \
# 4  https://www.plazavea.com.pe/bebidas/aguas/agua...            0
#
#                     Title                                 MetaTagDescription  \
# 4  Agua Tonica | plazaVea  Agua Tonica en oferta y al mejor precio de ven...
#
#   parent_id
# 4         6

# %%
file_name_categories_csv = f'plazavea_categories_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_categories_csv, index=False)

# %%
cats = df.query("parent_id == ''")['id'].to_list()
print(cats)
# Out:
# [2, 297, 399, 620, 431, 679, 77, 681, 898, 210, 621, 1138, 493, 666, 814, 845, 922, 1098, 1105, 478, 1046, 1073, 1383, 1503, 678, 1409, 1765, 1767, 2331, 2941, 3013, 3072, 3086, 3174, 3201, 3253, 4180]

# %%
import time

products = []

for cat in cats:
    start = 0
    end = 49
    
    while True:
        time.sleep(1)
        url = f"https://www.plazavea.com.pe/api/catalog_system/pub/products/search?fq=C:{cat}&_from={start}&_to={end}&O=OrderByPriceDESC"
        
        response = requests.get(url)
        
        if response.status_code == 200 or response.status_code == 206:
            data = response.json()
            if not data:
                break
                 
            products.extend(data)
            start += 50
            end += 50
        else:
            break
    
    print(f"status_code = {response.status_code}")
    print(f"cat = {cat}, start = {start}, end = {end}")

 
file_name_productos_csv = f'productos_{fecha_hora_para_archivos}.json'

with open(file_name_productos_csv, 'w') as file:
    json.dump(products, file, indent=4)
# Out:
# status_code = 200
# cat = 2, start = 650, end = 699
# status_code = 400
# cat = 297, start = 2550, end = 2599
# status_code = 400
# cat = 399, start = 2550, end = 2599
# status_code = 400
# cat = 620, start = 2550, end = 2599
# status_code = 500
# cat = 431, start = 850, end = 899
# status_code = 500
# cat = 679, start = 2100, end = 2149
# status_code = 200
# cat = 77, start = 650, end = 699
# status_code = 500
# cat = 681, start = 600, end = 649
# status_code = 500
# cat = 898, start = 1600, end = 1649
# status_code = 200
# cat = 210, start = 450, end = 499
# status_code = 200
# cat = 621, start = 800, end = 849
# status_code = 500
# cat = 1138, start = 150, end = 199
# status_code = 500
# cat = 493, start = 450, end = 499
# status_code = 500
# cat = 666, start = 1950, end = 1999
# status_code = 200
# cat = 814, start = 500, end = 549
# status_code = 200
# cat = 845, start = 600, end = 649
# status_code = 400
# cat = 922, start = 2550, end = 2599
# status_code = 400
# cat = 1098, start = 2550, end = 2599
# status_code = 500
# cat = 1105, start = 200, end = 249
# status_code = 200
# cat = 478, start = 1000, end = 1049
# status_code = 200
# cat = 1046, start = 450, end = 499
# status_code = 200
# cat = 1073, start = 250, end = 299
# status_code = 200
# cat = 1383, start = 1200, end = 1249
# status_code = 400
# cat = 1503, start = 2550, end = 2599
# status_code = 500
# cat = 678, start = 1300, end = 1349
# status_code = 400
# cat = 1409, start = 2550, end = 2599
# status_code = 500
# cat = 1765, start = 1150, end = 1199
# status_code = 500
# cat = 1767, start = 1550, end = 1599
# status_code = 200
# cat = 2331, start = 0, end = 49
# status_code = 500
# cat = 2941, start = 0, end = 49
# status_code = 500
# cat = 3013, start = 750, end = 799
# status_code = 500
# cat = 3072, start = 200, end = 249
# status_code = 500
# cat = 3086, start = 200, end = 249
# status_code = 500
# cat = 3174, start = 550, end = 599
# status_code = 500
# cat = 3201, start = 300, end = 349
# status_code = 400
# cat = 3253, start = 2550, end = 2599
# status_code = 500
# cat = 4180, start = 750, end = 799

# %%
print(len(products))
# Out:
# 41304

# %%
columns = ['productId', 'productName', 'brand', 'brandId', 'brandImageUrl','categoryId',
           'productTitle', 'metaTagDescription', 'categories', 'categoriesIds', 'link', 'Vendido por',
           'Descripción del producto', 'Presentación', 'Presentación/Empaque', 'Pack', 'Porción Sugerida',
           'Azúcares Por Porción', 'Carbohidratos Por Porción', 'Descripción Nutricional', 'Grasas Por Porción',
           'Advertencias de consumo', 'itemId', 'ean', 'imageUrl', 'Value', 'IsAvailable', 'AvailableQuantity',
           'Price', 'ListPrice', 'PriceWithoutDiscount', 'PriceValidUntil', 'Created']

df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [productId, productName, brand, brandId, brandImageUrl, categoryId, productTitle, metaTagDescription, categories, categoriesIds, link, Vendido por, Descripción del producto, Presentación, Presentación/Empaque, Pack, Porción Sugerida, Azúcares Por Porción, Carbohidratos Por Porción, Descripción Nutricional, Grasas Por Porción, Advertencias de consumo, itemId, ean, imageUrl, Value, IsAvailable, AvailableQuantity, Price, ListPrice, PriceWithoutDiscount, PriceValidUntil, Created]
# Index: []
#
# [0 rows x 33 columns]

# %%
for product in products:
  print(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'])
  break
# Out:
# 57.9
# 3000-01-02T00:00:00Z
# 57.9
# 57.9

# %%
print(json.dumps(products[3099], indent=4))
# Out:
# {
#     "productId": "100859353",
#     "productName": "Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g",
#     "brand": "LAMPI\u00d1A",
#     "brandId": 40230196,
#     "brandImageUrl": null,
#     "linkText": "crema-corporal-numae-110g-3-crema-depiladora-lampina-120g-100859353",
#     "productReference": "-",
#     "productReferenceCode": "-",
#     "categoryId": "2852",
#     "productTitle": "Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g | plazaVea",
#     "metaTagDescription": "\u00a1Compra Online Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g desde donde est\u00e9s en plazaVea.com.pe!",
#     "releaseDate": "2023-10-21T00:00:00Z",
#     "clusterHighlights": {},
#     "productClusters": {},
#     "searchableClusters": {},
#     "categories": [
#         "/Cuidado Personal y Salud/Depilaci\u00f3n/Cremas para Depilar/",
#         "/Cuidado Personal y Salud/Depilaci\u00f3n/",
#         "/Cuidado Personal y Salud/"
#     ],
#     "categoriesIds": [
#         "/297/2849/2852/",
#         "/297/2849/",
#         "/297/"
#     ],
#     "link": "https://www.plazavea.com.pe/crema-corporal-numae-110g-3-crema-depiladora-lampina-120g-100859353/p",
#     "Tipo de Producto": [
#         "Sellercenter"
#     ],
#     "Vendido por": [
#         "Marcas Aliadas"
#     ],
#     "Componentes del Producto": [
#         "Tipo de Producto",
#         "Vendido por"
#     ],
#     "Tipo de env\u00edo": [
#         "Despacho a domicilio"
#     ],
#     "M\u00e9todo de Entrega": [
#         "Tipo de env\u00edo"
#     ],
#     "Presentaci\u00f3n": [
#         "Caja"
#     ],
#     "Hipoalerg\u00e9nico": [
#         "S\u00cd"
#     ],
#     "Instrucciones De Uso": [
#         "Aplicar una cantidad adecuada de crema en las \u00e1reas del cuerpo que necesiten hidrataci\u00f3n., Masajear suavemente hasta su total absorci\u00f3n."
#     ],
#     "Edad Sugerida De Uso": [
#         "18 a mas"
#     ],
#     "Advertencias De Almacenamiento": [
#         "En un ambiente ventilado"
#     ],
#     "Especificaciones": [
#         "Presentaci\u00f3n",
#         "Hipoalerg\u00e9nico",
#         "Instrucciones De Uso",
#         "Edad Sugerida De Uso",
#         "Advertencias De Almacenamiento"
#     ],
#     "allSpecifications": [
#         "Tipo de Producto",
#         "Vendido por",
#         "Tipo de env\u00edo",
#         "Presentaci\u00f3n",
#         "Hipoalerg\u00e9nico",
#         "Instrucciones De Uso",
#         "Edad Sugerida De Uso",
#         "Advertencias De Almacenamiento"
#     ],
#     "allSpecificationsGroups": [
#         "Componentes del Producto",
#         "M\u00e9todo de Entrega",
#         "Especificaciones"
#     ],
#     "description": "Producto: 1 Crema corporal Numae \nProducto: 3 Crema depiladora Lampi\u00f1a \nCantidad: Lampi\u00f1a 120g c/u\nCantidad: Numea 110g\nBeneficio: Hidrata, nutre, mejora la textura, suaviza, proporciona frescura.",
#     "items": [
#         {
#             "itemId": "11174045",
#             "name": "Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g",
#             "nameComplete": "Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g",
#             "complementName": "",
#             "ean": "",
#             "referenceId": [
#                 {
#                     "Key": "RefId",
#                     "Value": "IMPORTACIONESVOCHEIRL-1681852502960"
#                 }
#             ],
#             "measurementUnit": "un",
#             "unitMultiplier": 1.0,
#             "modalType": null,
#             "isKit": false,
#             "images": [
#                 {
#                     "imageId": "28388404",
#                     "imageLabel": "",
#                     "imageTag": "<img src=\"~/arquivos/ids/28388404-#width#-#height#/image-0.jpg?v=638363720061800000\" width=\"#width#\" height=\"#height#\" alt=\"\" id=\"\" />",
#                     "imageUrl": "https://plazavea.vteximg.com.br/arquivos/ids/28388404/image-0.jpg?v=638363720061800000",
#                     "imageText": null,
#                     "imageLastModified": "2023-11-23T21:33:26.1800000Z"
#                 },
#                 {
#                     "imageId": "28388425",
#                     "imageLabel": "",
#                     "imageTag": "<img src=\"~/arquivos/ids/28388425-#width#-#height#/image-1.jpg?v=638363720071470000\" width=\"#width#\" height=\"#height#\" alt=\"\" id=\"\" />",
#                     "imageUrl": "https://plazavea.vteximg.com.br/arquivos/ids/28388425/image-1.jpg?v=638363720071470000",
#                     "imageText": null,
#                     "imageLastModified": "2023-11-23T21:33:27.1470000Z"
#                 }
#             ],
#             "sellers": [
#                 {
#                     "sellerId": "IMPORTACIONESVOCHEIRL",
#                     "sellerName": "Importaciones Sumak",
#                     "addToCartLink": "https://www.plazavea.com.pe/checkout/cart/add?sku=11174045&qty=1&seller=IMPORTACIONESVOCHEIRL&sc=1&price=13790&cv=_&sc=1",
#                     "sellerDefault": true,
#                     "commertialOffer": {
#                         "DeliverySlaSamplesPerRegion": {
#                             "0": {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         },
#                         "Installments": [
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Safetypay",
#                                 "PaymentSystemGroupName": "safetypayPaymentGroup",
#                                 "Name": "Safetypay \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Lot\u00e9rica",
#                                 "PaymentSystemGroupName": "lotteryPaymentGroup",
#                                 "Name": "Lot\u00e9rica \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "AGORAWEB",
#                                 "PaymentSystemGroupName": "custom202PaymentGroupPaymentGroup",
#                                 "Name": "AGORAWEB \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Tarjetas-Credito-Debito-PROM",
#                                 "PaymentSystemGroupName": "custom206PaymentGroupPaymentGroup",
#                                 "Name": "Tarjetas-Credito-Debito-PROM \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Agora-Visa",
#                                 "PaymentSystemGroupName": "custom208PaymentGroupPaymentGroup",
#                                 "Name": "Agora-Visa \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Tarjetas-Interbank",
#                                 "PaymentSystemGroupName": "custom209PaymentGroupPaymentGroup",
#                                 "Name": "Tarjetas-Interbank \u00e0 vista"
#                             },
#                             {
#                                 "Value": 137.9,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 137.9,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Tarjeta-Oh-Cuotas",
#                                 "PaymentSystemGroupName": "custom210PaymentGroupPaymentGroup",
#                                 "Name": "Tarjeta-Oh-Cuotas \u00e0 vista"
#                             }
#                         ],
#                         "DiscountHighLight": [],
#                         "GiftSkuIds": [],
#                         "Teasers": [],
#                         "PromotionTeasers": [],
#                         "BuyTogether": [],
#                         "ItemMetadataAttachment": [],
#                         "Price": 137.9,
#                         "ListPrice": 147.0,
#                         "PriceWithoutDiscount": 137.9,
#                         "FullSellingPrice": 137.9,
#                         "RewardValue": 0.0,
#                         "PriceValidUntil": "2026-04-05T00:00:00Z",
#                         "AvailableQuantity": 50,
#                         "IsAvailable": true,
#                         "Tax": 0.0,
#                         "DeliverySlaSamples": [
#                             {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         ],
#                         "GetInfoErrorMessage": null,
#                         "CacheVersionUsedToCallCheckout": "_",
#                         "PaymentOptions": {
#                             "installmentOptions": [
#                                 {
#                                     "paymentSystem": "38",
#                                     "bin": null,
#                                     "paymentName": "Safetypay",
#                                     "paymentGroupName": "safetypayPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "51",
#                                     "bin": null,
#                                     "paymentName": "Lot\u00e9rica",
#                                     "paymentGroupName": "lotteryPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "202",
#                                     "bin": null,
#                                     "paymentName": "AGORAWEB",
#                                     "paymentGroupName": "custom202PaymentGroupPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "206",
#                                     "bin": null,
#                                     "paymentName": "Tarjetas-Credito-Debito-PROM",
#                                     "paymentGroupName": "custom206PaymentGroupPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "208",
#                                     "bin": null,
#                                     "paymentName": "Agora-Visa",
#                                     "paymentGroupName": "custom208PaymentGroupPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "209",
#                                     "bin": null,
#                                     "paymentName": "Tarjetas-Interbank",
#                                     "paymentGroupName": "custom209PaymentGroupPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "210",
#                                     "bin": null,
#                                     "paymentName": "Tarjeta-Oh-Cuotas",
#                                     "paymentGroupName": "custom210PaymentGroupPaymentGroup",
#                                     "value": 13790,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 13790,
#                                             "total": 13790,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "PLAZAVEA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 13790,
#                                                     "total": 13790
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "paymentSystems": [
#                                 {
#                                     "id": 208,
#                                     "name": "Agora-Visa",
#                                     "groupName": "custom208PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "208",
#                                     "template": "custom208PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "Agora Visa",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-25T21:34:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 202,
#                                     "name": "AGORAWEB",
#                                     "groupName": "custom202PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "202",
#                                     "template": "custom202PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "AGORAWEB",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-25T21:34:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 51,
#                                     "name": "Lot\u00e9rica",
#                                     "groupName": "lotteryPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "51",
#                                     "template": "lotteryPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-30T21:33:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 206,
#                                     "name": "Tarjetas-Credito-Debito-PROM",
#                                     "groupName": "custom206PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "206",
#                                     "template": "custom206PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "Otras tarjetas de Cr\u00e9dito y D\u00e9bito",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-25T21:34:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 210,
#                                     "name": "Tarjeta-Oh-Cuotas",
#                                     "groupName": "custom210PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "210",
#                                     "template": "custom210PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "Tarjeta Oh! Visa y Mastercard",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-25T21:34:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 209,
#                                     "name": "Tarjetas-Interbank",
#                                     "groupName": "custom209PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "209",
#                                     "template": "custom209PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "Tarjetas Interbank",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-25T21:34:01.0503156Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 38,
#                                     "name": "Safetypay",
#                                     "groupName": "safetypayPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "38",
#                                     "template": "safetypayPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2023-11-30T21:33:01.0503156Z",
#                                     "availablePayments": null
#                                 }
#                             ],
#                             "payments": [],
#                             "giftCards": [],
#                             "giftCardMessages": [],
#                             "availableAccounts": [],
#                             "availableTokens": []
#                         }
#                     }
#                 },
#                 {
#                     "sellerId": "1",
#                     "sellerName": "Plaza Vea",
#                     "addToCartLink": "https://www.plazavea.com.pe/checkout/cart/add?sku=11174045&qty=1&seller=1&sc=1&price=0&cv=_&sc=1",
#                     "sellerDefault": false,
#                     "commertialOffer": {
#                         "DeliverySlaSamplesPerRegion": {},
#                         "Installments": [],
#                         "DiscountHighLight": [],
#                         "GiftSkuIds": [],
#                         "Teasers": [],
#                         "PromotionTeasers": [],
#                         "BuyTogether": [],
#                         "ItemMetadataAttachment": [],
#                         "Price": 0.0,
#                         "ListPrice": 0.0,
#                         "PriceWithoutDiscount": 0.0,
#                         "FullSellingPrice": null,
#                         "RewardValue": 0.0,
#                         "PriceValidUntil": null,
#                         "AvailableQuantity": 0,
#                         "IsAvailable": false,
#                         "Tax": 0.0,
#                         "DeliverySlaSamples": [],
#                         "GetInfoErrorMessage": "Code: withoutStock | Status:error | Message: El \u00edtem Crema Corporal Numae 110g + 3 Crema depiladora Lampi\u00f1a 120g no tiene inventario",
#                         "CacheVersionUsedToCallCheckout": "_",
#                         "PaymentOptions": {
#                             "installmentOptions": [],
#                             "paymentSystems": [],
#                             "payments": [],
#                             "giftCards": [],
#                             "giftCardMessages": [],
#                             "availableAccounts": [],
#                             "availableTokens": []
#                         }
#                     }
#                 }
#             ],
#             "Videos": [],
#             "estimatedDateArrival": null
#         }
#     ]
# }

# %%
# print(json.dumps(products, indent=4))

# %%
def print_value(value, key):
    if value:
        print(f"{key} = {value}")
    else:
        print(f"{key} = None")

# %%
from bs4 import BeautifulSoup

def clean_html(html_code):
    if html_code is None:
        return ''
    if isinstance(html_code, list):
        html_code = ' '.join(html_code)
    soup = BeautifulSoup(html_code, 'html.parser')
    return soup.get_text()

# %%
def get_product_data(product, fecha_db):
    product['Created'] = fecha_db
    new_product = {}
    new_product['productId'] = product.get('productId')
    new_product['productName'] = product.get('productName')
    new_product['brand'] = product.get('brand')
    new_product['brandId'] = product.get('brandId')
    new_product['brandImageUrl'] = product.get('brandImageUrl')
    new_product['categoryId'] = product.get('categoryId')
    new_product['productTitle'] = product.get('productTitle')
    new_product['metaTagDescription'] = product.get('metaTagDescription')
    new_product['categories'] = product.get('categories')
    new_product['categoriesIds'] = product.get('categoriesIds')
    new_product['link'] = product.get('link')
    new_product['Vendido por'] = product.get('Vendido por')
    new_product['Descripción del producto'] = clean_html(product.get('Descripción del producto'))
    new_product['Presentación'] = product.get('Presentación')
    new_product['Presentación/Empaque'] = product.get('Presentación/Empaque')
    new_product['Pack'] = product.get('Pack')
    new_product['Porción Sugerida'] = product.get('Porción Sugerida')
    new_product['Azúcares Por Porción'] = product.get('Azúcares Por Porción')
    new_product['Carbohidratos Por Porción'] = product.get('Carbohidratos Por Porción')
    new_product['Descripción Nutricional'] = product.get('Descripción Nutricional')
    new_product['Grasas Por Porción'] = product.get('Grasas Por Porción')
    new_product['Advertencias de consumo'] = product.get('Advertencias de consumo')
    
    if product['items']:
        new_product['itemId'] = product['items'][0].get('itemId', None)
        new_product['ean'] = product['items'][0].get('ean', None)
        if product['items'][0]['images']:
            new_product['imageUrl'] = product['items'][0]['images'][0].get('imageUrl', None)
            if product['items'][0]['sellers']:
                commertial_offer = product['items'][0]['sellers'][0].get('commertialOffer', {})
                if commertial_offer.get('Installments'):
                    new_product['Value'] = commertial_offer['Installments'][0].get('Value', None)
                new_product['IsAvailable'] = commertial_offer.get('IsAvailable', None)
                new_product['AvailableQuantity'] = commertial_offer.get('AvailableQuantity', None)
                new_product['Price'] = commertial_offer.get('Price', None)
                new_product['ListPrice'] = commertial_offer.get('ListPrice', None)
                new_product['PriceWithoutDiscount'] = commertial_offer.get('PriceWithoutDiscount', None)
                new_product['PriceValidUntil'] = commertial_offer.get('PriceValidUntil', None)

    new_product['Created'] = product['Created']
    
    return new_product

# %%
# Para validar que los datos se están extrayendo correctamente

i = 0
for product in products:
    i += 1
    product['Created'] = fecha_hora_lima_db()
    print_value(product.get('productId'), 'productId')
    print_value(product.get('productName'), 'productName')
    print_value(product.get('brand'), 'brand')
    print_value(product.get('brandId'), 'brandId')
    print_value(product.get('brandImageUrl'), 'brandImageUrl')
    print_value(product.get('categoryId'), 'categoryId')
    print_value(product.get('productTitle'), 'productTitle')
    print_value(product.get('metaTagDescription'), 'metaTagDescription')
    print_value(product.get('categories'), 'categories')
    print_value(product.get('categoriesIds'), 'categoriesIds')
    print_value(product.get('link'), 'link')
    print_value(product.get('Vendido por'), 'Vendido por')
    print_value(clean_html(product.get('Descripción del producto')), 'Descripción del producto')
    print_value(product.get('Presentación'), 'Presentación')
    print_value(product.get('Presentación/Empaque'), 'Presentación/Empaque')
    print_value(product.get('Pack'), 'Pack')
    print_value(product.get('Porción Sugerida'), 'Porción Sugerida')
    print_value(product.get('Azúcares Por Porción'), 'Azúcares Por Porción')
    print_value(product.get('Carbohidratos Por Porción'), 'Carbohidratos Por Porción')
    print_value(product.get('Descripción Nutricional'), 'Descripción Nutricional')
    print_value(product.get('Grasas Por Porción'), 'Grasas Por Porción')
    print_value(product.get('Advertencias de consumo'), 'Advertencias de consumo')
    print_value(product['items'][0]['itemId'], 'itemId')
    print_value(product['items'][0]['ean'], 'ean')
    print_value(product['items'][0]['images'][0]['imageUrl'], 'imageUrl')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'], 'Value')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['IsAvailable'], 'IsAvailable')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['AvailableQuantity'], 'AvailableQuantity')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Price'], 'Price')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'], 'ListPrice')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'], 'PriceWithoutDiscount')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'], 'PriceValidUntil')
    print_value(product['Created'], 'Created')
    
    if i == 3:
        break
# Out:
# productId = 24015
# productName = Agua Tónica BRITVIC Paquete 12un Lata 150ml
# brand = BRITVIC
# brandId = 66825
# brandImageUrl = None
# categoryId = 952
# productTitle = Agua Tónica BRITVIC Paquete 12un Lata 150ml | plazaVea
# metaTagDescription = ¡Compra Online Agua Tónica BRITVIC Paquete 12un Lata 150ml desde donde estés en plazaVea.com.pe!
# categories = ['/Bebidas/Aguas/Agua Tónica/', '/Bebidas/Aguas/', '/Bebidas/']
# categoriesIds = ['/2/6/952/', '/2/6/', '/2/']
# link = https://www.plazavea.com.pe/agua-tonica-britvic-paquete-12un-x-lata-150ml/p
# Vendido por = ['plazaVea']
# Descripción del producto =
#
#
#
# Importante destacarAgua tónica Marca: BRITVIC  Contenido: 12un de 150ml
#
#
#
#
# Descripción del productoAGUAS
# plazaVea presenta una gran variedad de Bebidas para que elijas tu favorita de acuerdo a diferentes situaciones u ocasiones especiales. Hidratarse es muy importante para el correcto cuidado de nuestro organismo, además que nos ayuda a lucir mejor, porque una piel hidratada se refleja siempre en el exterior. Por tal motivo, te ofrecemos diferentes presentaciones de Aguas: agua en sixpack, agua en bidón, agua personal, agua de 2.5 litros y más.
# Puedes elegir entre Agua Mineral y Agua de Mesa en las marcas más populares del mercado. También puedes revisar nuestras opciones de Aguas Saborizadas para que te hidrates con una opción más rica pero libre de azúcares. Finalmente, si lo tuyo son las Aguas Tónicas te ofrecemos las mejores opciones en sabor y presentación para que elijas tu favorita a precios bajos todos los días.
# ¡Conoce la mejor variedad de  Agua Mineral en plazaVea Online!
#
# Descubre todas las variedades que esta Agua Mineral te ofrece a través de la tienda Online de plazaVea. Elige tu favorita, arma tu pedido desde donde estés y compra de forma rápida y práctica.
# Presentación = ['Paquete Lata']
# Presentación/Empaque = ['Lata']
# Pack = ['12', '12']
# Porción Sugerida = ['100ml', '100ml']
# Azúcares Por Porción = ['5.8g', '5.8g']
# Carbohidratos Por Porción = ['5.8g', '5.8g']
# Descripción Nutricional = ['Libre de gluten.', 'Libre de gluten.']
# Grasas Por Porción = ['0g', '0g']
# Advertencias de consumo = ['Consumir preferentemente antes de la fecha indicada en el envase.', 'Consumir preferentemente antes de la fecha indicada en el envase.']
# itemId = 23963
# ean = None
# imageUrl = https://plazavea.vteximg.com.br/arquivos/ids/29305726/20126080.jpg?v=638582180961800000
# Value = 57.9
# IsAvailable = True
# AvailableQuantity = 8
# Price = 57.9
# ListPrice = 57.9
# PriceWithoutDiscount = 57.9
# PriceValidUntil = 3000-01-02T00:00:00Z
# Created = 2024-10-08 16:01:11
# productId = 100792738
# productName = Agua Tónica BRTIVIC Low Calorie Lata 150ml Paquete 12un
# brand = BRITVIC
# brandId = 66825
# brandImageUrl = None
# categoryId = 952
# productTitle = Agua Tónica BRTIVIC Low Calorie Lata 150ml Paquete 12un | plazaVea
# metaTagDescription = ¡Compra Online Agua Tónica BRTIVIC Low Calorie Lata 150ml Paquete 12un desde donde estés en plazaVea.com.pe!
# categories = ['/Bebidas/Aguas/Agua Tónica/', '/Bebidas/Aguas/', '/Bebidas/']
# categoriesIds = ['/2/6/952/', '/2/6/', '/2/']
# link = https://www.plazavea.com.pe/agua-tonica-brtivic-low-calorie-lata-150ml-paquete-12un/p
# Vendido por = ['plazaVea']
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = ['100 ml']
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 11067698
# ean = 7750465006187
# imageUrl = https://plazavea.vteximg.com.br/arquivos/ids/29305733/20357534.jpg?v=638582181234900000
# Value = 57.9
# IsAvailable = True
# AvailableQuantity = 6
# Price = 57.9
# ListPrice = 57.9
# PriceWithoutDiscount = 57.9
# PriceValidUntil = 3000-01-02T00:00:00Z
# Created = 2024-10-08 16:01:11
# productId = 100792736
# productName = Ginger Ale Beer BRITVIC Lata 150ml Paquete 12un
# brand = BRITVIC
# brandId = 66825
# brandImageUrl = None
# categoryId = 1654
# productTitle = Ginger Ale Beer BRITVIC Lata 150ml Paquete 12un | plazaVea
# metaTagDescription = ¡Compra Online Ginger Ale Beer BRITVIC Lata 150ml Paquete 12un desde donde estés en plazaVea.com.pe!
# categories = ['/Bebidas/Gaseosas/Ginger Ale/', '/Bebidas/Gaseosas/', '/Bebidas/']
# categoriesIds = ['/2/7/1654/', '/2/7/', '/2/']
# link = https://www.plazavea.com.pe/ginger-ale-beer-britvic-lata-150ml-paquete-12un/p
# Vendido por = ['plazaVea']
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = ['100 ml']
# Azúcares Por Porción = ['8.5 g']
# Carbohidratos Por Porción = ['8.5 g']
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 11067696
# ean = 7750465008679
# imageUrl = https://plazavea.vteximg.com.br/arquivos/ids/29305731/20357378.jpg?v=638582181156900000
# Value = 57.9
# IsAvailable = True
# AvailableQuantity = 8
# Price = 57.9
# ListPrice = 57.9
# PriceWithoutDiscount = 57.9
# PriceValidUntil = 3000-01-02T05:00:00Z
# Created = 2024-10-08 16:01:11

# %%
for product in products:
  new_product = get_product_data(product, fecha_hora_para_base_de_datos)
  df.loc[len(df)] = new_product

# %%
df.sample(n=5)
# Out:
#        productId                                        productName  \
# 28578  101025107        Cuna Corral Mecedora Ebaby Sally EB716 Azul
# 38416  100827504                      Autoradio Pioneer DEH S4250BT
# 3939   101132849  Cepillo Manual de Pelusas Amarillo Y+Post-it a...
# 18861  101139549  Carro a Batería Chevrolet Daewon con Pantalla ...
# 22375  100010568                    Juego de Sala 3 2 Denieke Beige
#
#               brand   brandId brandImageUrl categoryId  \
# 28578         EBABY     73923          None        657
# 38416       PIONEER     60617          None       3261
# 3939   RYBIU IMPORT  40228561          None        418
# 18861     IMPORTADO  40230546          None       1584
# 22375    ALTO HOGAR  40223493          None       1120
#
#                                             productTitle  \
# 28578  Cuna Corral Mecedora Ebaby Sally EB716 Azul | ...
# 38416           Autoradio Pioneer DEH S4250BT | plazaVea
# 3939                                                None
# 18861                                               None
# 22375         Juego de Sala 3 2 Denieke Beige | plazaVea
#
#                                       metaTagDescription  \
# 28578  ¡Compra online Cuna Corral Mecedora Ebaby Sall...
# 38416  ¡Compra online Autoradio Pioneer DEH S4250BTde...
# 3939   Si quieres mantener tus prendas libre de pelos...
# 18861  ¡Transforma cada paseo en una emocionante aven...
# 22375  ¡Compra online Juego de Sala 3 2 Denieke Azul ...
#
#                                               categories  \
# 28578  [/Bebé e Infantil/Dormitorio Bebé e Infantil/C...
# 38416  [/Automotriz/Accesorios para Auto/Autoradios/,...
# 3939   [/Limpieza/Cuidado de la Ropa/Accesorios para ...
# 18861  [/Juguetes y Juegos/Juguetería/Juguetes a Bate...
# 22375  [/Muebles/Muebles de Sala/Juegos de sala/, /Mu...
#
#                                            categoriesIds  ...       ean  \
# 28578             [/1503/1435/657/, /1503/1435/, /1503/]  ...
# 38416            [/3253/3254/3261/, /3253/3254/, /3253/]  ...
# 3939                   [/399/400/418/, /399/400/, /399/]  ...
# 18861                 [/922/923/1584/, /922/923/, /922/]  ...
# 22375  [/1098/1030/1120/, /1098/1030/, /1098/, /1765/...  ...  30012124
#
#                                                 imageUrl   Value IsAvailable  \
# 28578  https://plazavea.vteximg.com.br/arquivos/ids/2...   379.0        True
# 38416  https://plazavea.vteximg.com.br/arquivos/ids/2...   620.0        True
# 3939   https://plazavea.vteximg.com.br/arquivos/ids/2...    39.9        True
# 18861  https://plazavea.vteximg.com.br/arquivos/ids/2...  2839.0        True
# 22375  https://plazavea.vteximg.com.br/arquivos/ids/1...  3499.0        True
#
#       AvailableQuantity   Price ListPrice PriceWithoutDiscount  \
# 28578                10   379.0     499.0                379.0
# 38416                10   620.0     620.0                620.0
# 3939                 50    39.9      57.0                 39.9
# 18861                10  2839.0    5599.0               2839.0
# 22375                13  3499.0    3800.0               3499.0
#
#             PriceValidUntil              Created
# 28578  2030-01-31T00:00:00Z  2024-10-08 15:28:01
# 38416                  None  2024-10-08 15:28:01
# 3939   2029-08-22T00:00:00Z  2024-10-08 15:28:01
# 18861  2029-12-31T00:00:00Z  2024-10-08 15:28:01
# 22375   2028-01-01T00:00:00  2024-10-08 15:28:01
#
# [5 rows x 33 columns]

# %%
df[['productId', 'productName', 'brand', 'categoryId', 'link', 'Price', 'AvailableQuantity']].sample(n=8)
# Out:
#        productId                                        productName  \
# 2295   100442979  Aminoácidos Level Pro  Bcaa Level 8000 1000gr ...
# 25562  100796574                   Crema de Ajo FERYMAR Envase 250g
# 5478   100099486                  Limpiador POETT Bebé Botella 1.8L
# 9506   100982722  Aire Acondicionado Split Khöne Inverter KMI-18...
# 32491  100280567  Dormitorio 3 Cajones PARAISO Royal Elizabeth C...
# 17555  100629088  Libreta Moustachine Classic Leather Look Negro...
# 36081  101017636        Reloj Invicta 43929 Blanco, Titanio Hombres
# 11690      62885         Jugo Natural ECOFRESH Naranja Botella 1.8L
#
#              brand categoryId  \
# 2295     LEVEL PRO       1246
# 25562      FERYMAR       1681
# 5478         POETT        424
# 9506         KHÖNE        745
# 32491      PARAÍSO       3550
# 17555  MOUSTACHINE        904
# 36081      INVICTA       3049
# 11690     ECOFRESH       1764
#
#                                                     link    Price  \
# 2295   https://www.plazavea.com.pe/aminoacidos-level-...   189.90
# 25562  https://www.plazavea.com.pe/crema-de-ajo-ferym...    12.90
# 5478   https://www.plazavea.com.pe/limpiador-poett-be...     7.50
# 9506   https://www.plazavea.com.pe/aire-acondicionado...  2899.00
# 32491  https://www.plazavea.com.pe/dormitorio-3-cajon...  1599.00
# 17555  https://www.plazavea.com.pe/libreta-moustachin...    49.90
# 36081  https://www.plazavea.com.pe/reloj-invicta-4392...  2699.00
# 11690  https://www.plazavea.com.pe/jugo-natural-ecofr...    24.99
#
#        AvailableQuantity
# 2295                 999
# 25562                134
# 5478                  81
# 9506                  29
# 32491            1000000
# 17555                 20
# 36081                  3
# 11690                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41304 entries, 0 to 41303
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   productId                  41304 non-null  object
#  1   productName                41304 non-null  object
#  2   brand                      41304 non-null  object
#  3   brandId                    41304 non-null  int64
#  4   brandImageUrl              26 non-null     object
#  5   categoryId                 41304 non-null  object
#  6   productTitle               40729 non-null  object
#  7   metaTagDescription         41304 non-null  object
#  8   categories                 41304 non-null  object
#  9   categoriesIds              41304 non-null  object
#  10  link                       41304 non-null  object
#  11  Vendido por                41300 non-null  object
#  12  Descripción del producto   41304 non-null  object
#  13  Presentación               2722 non-null   object
#  14  Presentación/Empaque       3012 non-null   object
#  15  Pack                       94 non-null     object
#  16  Porción Sugerida           2115 non-null   object
#  17  Azúcares Por Porción       2073 non-null   object
#  18  Carbohidratos Por Porción  2156 non-null   object
#  19  Descripción Nutricional    1143 non-null   object
#  20  Grasas Por Porción         1510 non-null   object
#  21  Advertencias de consumo    1329 non-null   object
#  22  itemId                     41304 non-null  object
#  23  ean                        41304 non-null  object
#  24  imageUrl                   41304 non-null  object
#  25  Value                      39914 non-null  float64
#  26  IsAvailable                41304 non-null  bool
#  27  AvailableQuantity          41304 non-null  int64
#  28  Price                      41304 non-null  float64
#  29  ListPrice                  41304 non-null  float64
#  30  PriceWithoutDiscount       41304 non-null  float64
#  31  PriceValidUntil            33174 non-null  object
#  32  Created                    41304 non-null  object
# dtypes: bool(1), float64(4), int64(2), object(26)
# memory usage: 10.4+ MB

# %%
df['product_uri_json'] = df['productId'].apply(lambda x: f'https://www.plazavea.com.pe/api/catalog_system/pub/products/search?fq=productId:{x}')

# %%
df['product_uri_json'].sample(n=5)
# Out:
# 26955    https://www.plazavea.com.pe/api/catalog_system...
# 14844    https://www.plazavea.com.pe/api/catalog_system...
# 34448    https://www.plazavea.com.pe/api/catalog_system...
# 18717    https://www.plazavea.com.pe/api/catalog_system...
# 25050    https://www.plazavea.com.pe/api/catalog_system...
# Name: product_uri_json, dtype: object

# %%
file_name_productos_csv = f'plazavea-productos_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_productos_csv, index=False)
