# %%
from datetime import datetime
import pytz

def fecha_hora_lima():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y%m%d-%H%M%S')

def fecha_hora_lima_db():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y-%m-%d %H:%M:%S')

fecha_hora_para_archivos = fecha_hora_lima()
fecha_hora_para_base_de_datos = fecha_hora_lima_db()

# %%
import pandas as pd
import requests
import json

# URL del JSON
url = 'https://www.vivanda.com.pe/api/catalog_system/pub/category/tree/3'

# Solicitar el contenido JSON desde la URL
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    data = response.json()  # Convertir la respuesta en un objeto JSON
    file_name = f'categories_{fecha_hora_para_archivos}.json'
    
    # Guardar el JSON en un archivo
    with open(file_name, 'w') as file:
        json.dump(data, file, indent=4)

    print('El archivo JSON se ha guardado exitosamente.')
    with open(file_name, 'r') as file:
        data = json.load(file)
    print(len(data)) 
else:
    print(f'Error al obtener el JSON. Código de estado: {response.status_code}')
# Out:
# El archivo JSON se ha guardado exitosamente.
# 27

# %%
# file_path = 'vivanda_categories.json'
# 
# with open(file_path, 'r') as file:
#     data = json.load(file)
#     print(json.dumps(data, indent=4))

# %%
columns = ['id', 'name', 'hasChildren', 'url', 'NumChildren', 'Title', 'MetaTagDescription', 'parent_id']
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [id, name, hasChildren, url, NumChildren, Title, MetaTagDescription, parent_id]
# Index: []

# %%
for item in data:
  if item['hasChildren']:
    item['parent_id'] = ''
    item['NumChildren'] = len(item['children'])

    df.loc[len(df)] = item

    parent_id = item['id']

    for subitem in item['children']:
      subitem['parent_id'] = parent_id
      sub_parent_id = subitem['id']
      subitem['NumChildren'] = len(subitem['children'])

      df.loc[len(df)] = subitem

      if len(subitem['children']) > 0:
        for subsubitem in subitem['children']:
          subsubitem['parent_id'] = sub_parent_id
          subsubitem['NumChildren'] = len(subsubitem['children'])
          df.loc[len(df)] = subsubitem

# %%
df.query("id == 952")
# Out:
#       id                           name  hasChildren  \
# 640  952  Zapatillas Outdoor para Mujer        False
#
#                                                    url  NumChildren  \
# 640  https://www.vivanda.com.pe/moda/zapatillas-muj...            0
#
#                              Title MetaTagDescription parent_id
# 640  Zapatillas Outdoor para Mujer                          908

# %%
file_name_categories_csv = f'vivanda_categories_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_categories_csv, index=False)

# %%
cats = df.query("parent_id == ''")['id'].to_list()
print(cats)
# Out:
# [11, 12, 13, 15, 17, 18, 19, 20, 21, 22, 525, 487, 883, 902, 993, 995, 996, 997, 998, 999, 1000, 1001, 1003, 1610, 1622, 1746]

# %%
import time

products = []

for cat in cats:
    start = 0
    end = 49
    
    while True:
        time.sleep(1)
        url = f"https://www.vivanda.com.pe/api/catalog_system/pub/products/search?fq=C:{cat}&_from={start}&_to={end}&O=OrderByPriceDESC"
        
        response = requests.get(url)
        
        if response.status_code == 200 or response.status_code == 206:
            data = response.json()
            if not data:
                break
                 
            products.extend(data)
            start += 50
            end += 50
        else:
            break
    
    print(f"status_code = {response.status_code}")
    print(f"cat = {cat}, start = {start}, end = {end}")

 
file_name_productos_csv = f'productos_{fecha_hora_para_archivos}.json'

with open(file_name_productos_csv, 'w') as file:
    json.dump(products, file, indent=4)
# Out:
# status_code = 200
# cat = 11, start = 450, end = 499
# status_code = 200
# cat = 12, start = 400, end = 449
# status_code = 200
# cat = 13, start = 650, end = 699
# status_code = 200
# cat = 15, start = 700, end = 749
# status_code = 500
# cat = 17, start = 1500, end = 1549
# status_code = 200
# cat = 18, start = 450, end = 499
# status_code = 200
# cat = 19, start = 500, end = 549
# status_code = 200
# cat = 20, start = 1100, end = 1149
# status_code = 200
# cat = 21, start = 800, end = 849
# status_code = 200
# cat = 22, start = 900, end = 949
# status_code = 200
# cat = 525, start = 750, end = 799
# status_code = 200
# cat = 487, start = 400, end = 449
# status_code = 200
# cat = 883, start = 300, end = 349
# status_code = 200
# cat = 902, start = 0, end = 49
# status_code = 200
# cat = 993, start = 950, end = 999
# status_code = 200
# cat = 995, start = 150, end = 199
# status_code = 200
# cat = 996, start = 650, end = 699
# status_code = 200
# cat = 997, start = 550, end = 599
# status_code = 200
# cat = 998, start = 550, end = 599
# status_code = 500
# cat = 999, start = 1000, end = 1049
# status_code = 200
# cat = 1000, start = 400, end = 449
# status_code = 200
# cat = 1001, start = 150, end = 199
# status_code = 200
# cat = 1003, start = 50, end = 99
# status_code = 200
# cat = 1610, start = 200, end = 249
# status_code = 200
# cat = 1622, start = 150, end = 199
# status_code = 200
# cat = 1746, start = 1150, end = 1199

# %%
print(len(products))
# Out:
# 14285

# %%
columns = ['productId', 'productName', 'brand', 'brandId', 'brandImageUrl','categoryId',
           'productTitle', 'metaTagDescription', 'categories', 'categoriesIds', 'link', 'Vendido por',
           'Descripción del producto', 'Presentación', 'Presentación/Empaque', 'Pack', 'Porción Sugerida',
           'Azúcares Por Porción', 'Carbohidratos Por Porción', 'Descripción Nutricional', 'Grasas Por Porción',
           'Advertencias de consumo', 'itemId', 'ean', 'imageUrl', 'Value', 'IsAvailable', 'AvailableQuantity',
           'Price', 'ListPrice', 'PriceWithoutDiscount', 'PriceValidUntil', 'Created']

df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [productId, productName, brand, brandId, brandImageUrl, categoryId, productTitle, metaTagDescription, categories, categoriesIds, link, Vendido por, Descripción del producto, Presentación, Presentación/Empaque, Pack, Porción Sugerida, Azúcares Por Porción, Carbohidratos Por Porción, Descripción Nutricional, Grasas Por Porción, Advertencias de consumo, itemId, ean, imageUrl, Value, IsAvailable, AvailableQuantity, Price, ListPrice, PriceWithoutDiscount, PriceValidUntil, Created]
# Index: []
#
# [0 rows x 33 columns]

# %%
for product in products:
  print(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'])
  break
# Out:
# 35.39
# 3000-01-02T00:00:00Z
# 35.39
# 35.39

# %%
print(json.dumps(products[3099], indent=4))
# Out:
# {
#     "productId": "30141",
#     "productName": "Condimento 4 ESTACIONES Mix pescado Frasco 50Gr",
#     "brand": "4ESTACIONES",
#     "brandId": 205,
#     "brandImageUrl": null,
#     "linkText": "condimento-4-estaciones-mix-pescado-frasco-50gr",
#     "productReference": "988361",
#     "productReferenceCode": "988361",
#     "categoryId": "267",
#     "productTitle": "Condimento 4 ESTACIONES Mix pescado Frasco 50Gr| Vivanda",
#     "metaTagDescription": "\u00a1Compra online Condimento 4 ESTACIONES Mix pescado Frasco 50Gr al mejor precio en vivanda.com.pe desde donde est\u00e9s!",
#     "releaseDate": "2019-01-15T00:00:00Z",
#     "clusterHighlights": {},
#     "productClusters": {},
#     "searchableClusters": {},
#     "categories": [
#         "/Abarrotes/Salsas, Cremas y Condimentos/Otros Condimentos/",
#         "/Abarrotes/Salsas, Cremas y Condimentos/",
#         "/Abarrotes/"
#     ],
#     "categoriesIds": [
#         "/17/64/267/",
#         "/17/64/",
#         "/17/"
#     ],
#     "link": "https://www.vivanda.com.pe/condimento-4-estaciones-mix-pescado-frasco-50gr/p",
#     "Tipo de env\u00edo": [
#         "Despacho a domicilio",
#         "Delivery Express",
#         "Recojo en tienda"
#     ],
#     "Caracter\u00edsticas": [
#         "Tipo de env\u00edo"
#     ],
#     "allSpecifications": [
#         "Tipo de env\u00edo"
#     ],
#     "allSpecificationsGroups": [
#         "Caracter\u00edsticas"
#     ],
#     "description": "",
#     "items": [
#         {
#             "itemId": "30459",
#             "name": "Condimento 4 ESTACIONES Mix pescado Frasco 50Gr",
#             "nameComplete": "Condimento 4 ESTACIONES Mix pescado Frasco 50Gr",
#             "complementName": "",
#             "ean": "",
#             "referenceId": [
#                 {
#                     "Key": "RefId",
#                     "Value": "988361"
#                 }
#             ],
#             "measurementUnit": "un",
#             "unitMultiplier": 1.0,
#             "modalType": null,
#             "isKit": false,
#             "images": [
#                 {
#                     "imageId": "366081",
#                     "imageLabel": null,
#                     "imageTag": "<img src=\"~/arquivos/ids/366081-#width#-#height#/988361.jpg?v=637862409884570000\" width=\"#width#\" height=\"#height#\" alt=\"988361\" id=\"\" />",
#                     "imageUrl": "https://vivanda.vteximg.com.br/arquivos/ids/366081/988361.jpg?v=637862409884570000",
#                     "imageText": "988361",
#                     "imageLastModified": "2022-04-22T16:16:28.4570000Z"
#                 }
#             ],
#             "sellers": [
#                 {
#                     "sellerId": "1",
#                     "sellerName": "Vivanda",
#                     "addToCartLink": "https://www.vivanda.com.pe/checkout/cart/add?sku=30459&qty=1&seller=1&sc=1&price=700&cv=_&sc=1",
#                     "sellerDefault": true,
#                     "commertialOffer": {
#                         "DeliverySlaSamplesPerRegion": {
#                             "0": {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         },
#                         "Installments": [
#                             {
#                                 "Value": 7.0,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 7.0,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Tarjetas-Credito-Debito-VIVANDA",
#                                 "PaymentSystemGroupName": "custom206PaymentGroupPaymentGroup",
#                                 "Name": "Tarjetas-Credito-Debito-VIVANDA \u00e0 vista"
#                             },
#                             {
#                                 "Value": 7.0,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 7.0,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Agora-Visa",
#                                 "PaymentSystemGroupName": "custom208PaymentGroupPaymentGroup",
#                                 "Name": "Agora-Visa \u00e0 vista"
#                             },
#                             {
#                                 "Value": 7.0,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 7.0,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Tarjetas-Interbank-VIVANDA",
#                                 "PaymentSystemGroupName": "custom209PaymentGroupPaymentGroup",
#                                 "Name": "Tarjetas-Interbank-VIVANDA \u00e0 vista"
#                             }
#                         ],
#                         "DiscountHighLight": [],
#                         "GiftSkuIds": [],
#                         "Teasers": [],
#                         "PromotionTeasers": [],
#                         "BuyTogether": [],
#                         "ItemMetadataAttachment": [],
#                         "Price": 7.0,
#                         "ListPrice": 7.0,
#                         "PriceWithoutDiscount": 7.0,
#                         "FullSellingPrice": 7.0,
#                         "RewardValue": 0.0,
#                         "PriceValidUntil": "3000-01-02T00:00:00Z",
#                         "AvailableQuantity": 10,
#                         "IsAvailable": true,
#                         "Tax": 0.0,
#                         "DeliverySlaSamples": [
#                             {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         ],
#                         "GetInfoErrorMessage": null,
#                         "CacheVersionUsedToCallCheckout": "_",
#                         "PaymentOptions": {
#                             "installmentOptions": [
#                                 {
#                                     "paymentSystem": "206",
#                                     "bin": null,
#                                     "paymentName": "Tarjetas-Credito-Debito-VIVANDA",
#                                     "paymentGroupName": "custom206PaymentGroupPaymentGroup",
#                                     "value": 700,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 700,
#                                             "total": 700,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "VIVANDA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 700,
#                                                     "total": 700
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "208",
#                                     "bin": null,
#                                     "paymentName": "Agora-Visa",
#                                     "paymentGroupName": "custom208PaymentGroupPaymentGroup",
#                                     "value": 700,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 700,
#                                             "total": 700,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "VIVANDA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 700,
#                                                     "total": 700
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "209",
#                                     "bin": null,
#                                     "paymentName": "Tarjetas-Interbank-VIVANDA",
#                                     "paymentGroupName": "custom209PaymentGroupPaymentGroup",
#                                     "value": 700,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 700,
#                                             "total": 700,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "VIVANDA",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 700,
#                                                     "total": 700
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "paymentSystems": [
#                                 {
#                                     "id": 208,
#                                     "name": "Agora-Visa",
#                                     "groupName": "custom208PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "208",
#                                     "template": "custom208PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "tarjeta Agora Visa",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-10-12T18:00:00Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 209,
#                                     "name": "Tarjetas-Interbank-VIVANDA",
#                                     "groupName": "custom209PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "209",
#                                     "template": "custom209PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "tarjeta Interbank",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-10-12T18:00:00Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 206,
#                                     "name": "Tarjetas-Credito-Debito-VIVANDA",
#                                     "groupName": "custom206PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "206",
#                                     "template": "custom206PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "tarjetas de cr\u00e9dito o d\u00e9bito",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-10-12T18:00:00Z",
#                                     "availablePayments": null
#                                 }
#                             ],
#                             "payments": [],
#                             "giftCards": [],
#                             "giftCardMessages": [],
#                             "availableAccounts": [],
#                             "availableTokens": []
#                         }
#                     }
#                 }
#             ],
#             "Videos": [],
#             "estimatedDateArrival": null
#         }
#     ]
# }

# %%
# print(json.dumps(products, indent=4))

# %%
def print_value(value, key):
    if value:
        print(f"{key} = {value}")
    else:
        print(f"{key} = None")

# %%
from bs4 import BeautifulSoup

def clean_html(html_code):
    if html_code is None:
        return ''
    if isinstance(html_code, list):
        html_code = ' '.join(html_code)
    soup = BeautifulSoup(html_code, 'html.parser')
    return soup.get_text()

# %%
def get_product_data(product, fecha_db):
    product['Created'] = fecha_db
    new_product = {}
    new_product['productId'] = product.get('productId')
    new_product['productName'] = product.get('productName')
    new_product['brand'] = product.get('brand')
    new_product['brandId'] = product.get('brandId')
    new_product['brandImageUrl'] = product.get('brandImageUrl')
    new_product['categoryId'] = product.get('categoryId')
    new_product['productTitle'] = product.get('productTitle')
    new_product['metaTagDescription'] = product.get('metaTagDescription')
    new_product['categories'] = product.get('categories')
    new_product['categoriesIds'] = product.get('categoriesIds')
    new_product['link'] = product.get('link')
    new_product['Vendido por'] = product.get('Vendido por')
    new_product['Descripción del producto'] = clean_html(product.get('Descripción del producto'))
    new_product['Presentación'] = product.get('Presentación')
    new_product['Presentación/Empaque'] = product.get('Presentación/Empaque')
    new_product['Pack'] = product.get('Pack')
    new_product['Porción Sugerida'] = product.get('Porción Sugerida')
    new_product['Azúcares Por Porción'] = product.get('Azúcares Por Porción')
    new_product['Carbohidratos Por Porción'] = product.get('Carbohidratos Por Porción')
    new_product['Descripción Nutricional'] = product.get('Descripción Nutricional')
    new_product['Grasas Por Porción'] = product.get('Grasas Por Porción')
    new_product['Advertencias de consumo'] = product.get('Advertencias de consumo')
    
    if product['items']:
        new_product['itemId'] = product['items'][0].get('itemId', None)
        new_product['ean'] = product['items'][0].get('ean', None)
        if product['items'][0]['images']:
            new_product['imageUrl'] = product['items'][0]['images'][0].get('imageUrl', None)
            if product['items'][0]['sellers']:
                commertial_offer = product['items'][0]['sellers'][0].get('commertialOffer', {})
                if commertial_offer.get('Installments'):
                    new_product['Value'] = commertial_offer['Installments'][0].get('Value', None)
                new_product['IsAvailable'] = commertial_offer.get('IsAvailable', None)
                new_product['AvailableQuantity'] = commertial_offer.get('AvailableQuantity', None)
                new_product['Price'] = commertial_offer.get('Price', None)
                new_product['ListPrice'] = commertial_offer.get('ListPrice', None)
                new_product['PriceWithoutDiscount'] = commertial_offer.get('PriceWithoutDiscount', None)
                new_product['PriceValidUntil'] = commertial_offer.get('PriceValidUntil', None)

    new_product['Created'] = product['Created']
    
    return new_product

# %%
# Para validar que los datos se están extrayendo correctamente

i = 0
for product in products:
    i += 1
    product['Created'] = fecha_hora_lima_db()
    print_value(product.get('productId'), 'productId')
    print_value(product.get('productName'), 'productName')
    print_value(product.get('brand'), 'brand')
    print_value(product.get('brandId'), 'brandId')
    print_value(product.get('brandImageUrl'), 'brandImageUrl')
    print_value(product.get('categoryId'), 'categoryId')
    print_value(product.get('productTitle'), 'productTitle')
    print_value(product.get('metaTagDescription'), 'metaTagDescription')
    print_value(product.get('categories'), 'categories')
    print_value(product.get('categoriesIds'), 'categoriesIds')
    print_value(product.get('link'), 'link')
    print_value(product.get('Vendido por'), 'Vendido por')
    print_value(clean_html(product.get('Descripción del producto')), 'Descripción del producto')
    print_value(product.get('Presentación'), 'Presentación')
    print_value(product.get('Presentación/Empaque'), 'Presentación/Empaque')
    print_value(product.get('Pack'), 'Pack')
    print_value(product.get('Porción Sugerida'), 'Porción Sugerida')
    print_value(product.get('Azúcares Por Porción'), 'Azúcares Por Porción')
    print_value(product.get('Carbohidratos Por Porción'), 'Carbohidratos Por Porción')
    print_value(product.get('Descripción Nutricional'), 'Descripción Nutricional')
    print_value(product.get('Grasas Por Porción'), 'Grasas Por Porción')
    print_value(product.get('Advertencias de consumo'), 'Advertencias de consumo')
    print_value(product['items'][0]['itemId'], 'itemId')
    print_value(product['items'][0]['ean'], 'ean')
    print_value(product['items'][0]['images'][0]['imageUrl'], 'imageUrl')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'], 'Value')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['IsAvailable'], 'IsAvailable')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['AvailableQuantity'], 'AvailableQuantity')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Price'], 'Price')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'], 'ListPrice')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'], 'PriceWithoutDiscount')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'], 'PriceValidUntil')
    print_value(product['Created'], 'Created')
    
    if i == 3:
        break
# Out:
# productId = 100215830
# productName = Nectar Naranja ECOFRESH Botella 3.8L
# brand = ECOFRESH
# brandId = 72216
# brandImageUrl = None
# categoryId = 1672
# productTitle = Nectar Naranja ECOFRESH Botella 3.8L | Vivanda
# metaTagDescription = ¡Compra online Nectar Naranja ECOFRESH Botella 3.8L al mejor precio en vivanda.com.pe desde donde estés!
# categories = ['/Frutas y Verduras/Frutas/Jugos Naturales/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/11/24/1672/', '/11/24/', '/11/']
# link = https://www.vivanda.com.pe/jugo-nectar-de-naranja-ecofresh-botella-3-8l/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = ['Botella']
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 10338138
# ean = 7752705002379
# imageUrl = https://vivanda.vteximg.com.br/arquivos/ids/410323/20237284.jpg?v=638025870212830000
# Value = 35.39
# IsAvailable = True
# AvailableQuantity = 10
# Price = 35.39
# ListPrice = 35.39
# PriceWithoutDiscount = 35.39
# PriceValidUntil = 3000-01-02T00:00:00Z
# Created = 2024-10-14 15:37:48
# productId = 100215831
# productName = Nectar Tropical ECOFRESH Botella 3.8L
# brand = ECOFRESH
# brandId = 72216
# brandImageUrl = None
# categoryId = 1672
# productTitle = Nectar Tropical ECOFRESH Botella 3.8L | Vivanda
# metaTagDescription = ¡Compra online Nectar Tropical ECOFRESH Botella 3.8L al mejor precio en vivanda.com.pe desde donde estés!
# categories = ['/Frutas y Verduras/Frutas/Jugos Naturales/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/11/24/1672/', '/11/24/', '/11/']
# link = https://www.vivanda.com.pe/jugo-nectar-tropical-ecofresh-botella-3-8l/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = ['Botella']
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 10338139
# ean = 7752705002386
# imageUrl = https://vivanda.vteximg.com.br/arquivos/ids/410324/20238323.jpg?v=638025870242570000
# Value = 34.99
# IsAvailable = True
# AvailableQuantity = 10
# Price = 34.99
# ListPrice = 34.99
# PriceWithoutDiscount = 34.99
# PriceValidUntil = 3000-01-02T00:00:00Z
# Created = 2024-10-14 15:37:48
# productId = 11033
# productName = Frambuesa Entera GREEN FOOD Bolsa 400g
# brand = GREEN FOOD
# brandId = 57045
# brandImageUrl = None
# categoryId = 25
# productTitle = Frambuesa Entera GREEN FOOD Bolsa 400g | Vivanda
# metaTagDescription = ¡Compra online Frambuesa Entera GREEN FOOD Bolsa 400g al mejor precio en vivanda.com.pe desde donde estés!
# categories = ['/Frutas y Verduras/Frutas/Frutas Congeladas/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/11/24/25/', '/11/24/', '/11/']
# link = https://www.vivanda.com.pe/frambuesa-entera-green-food-bolsa-400g/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 11027
# ean = None
# imageUrl = https://vivanda.vteximg.com.br/arquivos/ids/405668/20109214.jpg?v=638017632551670000
# Value = 31.3
# IsAvailable = True
# AvailableQuantity = 100
# Price = 31.3
# ListPrice = 31.3
# PriceWithoutDiscount = 31.3
# PriceValidUntil = 3000-01-02T00:00:00Z
# Created = 2024-10-14 15:37:48

# %%
for product in products:
  new_product = get_product_data(product, fecha_hora_para_base_de_datos)
  df.loc[len(df)] = new_product

# %%
df.sample(n=5)
# Out:
#        productId                                        productName  \
# 13681  100215501          Cava MARIA AMOROS Semi Seco Botella 750ml
# 12271  100171583          Estacion de Bomberos GAME POWER 8722 Rojo
# 6680       50483             Platón YCHICAWA 10.5'' Blanco Hot Uysa
# 4119        4625  Gaseosa INCA KOLA Sin Azúcar Botella 500ml Paq...
# 3572        3605          Sopa Instantánea MARUCHAN Pollo Bolsa 85g
#
#               brand   brandId brandImageUrl categoryId  \
# 13681  MARIA AMOROS     77788          None       1759
# 12271    GAME POWER  36364656          None       1386
# 6680       YCHICAWA  36364632          None        802
# 4119      INCA KOLA     61625          None       1146
# 3572       MARUCHAN     62758          None        259
#
#                                             productTitle  \
# 13681  Cava MARIA AMOROS Semi Seco Botella 750ml | Vi...
# 12271  Estacion de Bomberos GAME POWER 8722 Rojo | Vi...
# 6680    Platón YCHICAWA 10.5'' Blanco Hot Uysa | Vivanda
# 4119   Gaseosa INCA KOLA Sin Azúcar Botella 500ml Paq...
# 3572   Sopa Instantánea MARUCHAN Pollo Bolsa 85g | Vi...
#
#                                       metaTagDescription  \
# 13681  ¡Compra online Cava MARIA AMOROS Semi Seco Bot...
# 12271  ¡Compra online Estacion de Bomberos GAME POWER...
# 6680   ¡Compra online Platón YCHICAWA 10.5'' Blanco H...
# 4119   ¡Compra online Gaseosa INCA KOLA Sin Azúcar Bo...
# 3572   ¡Compra Online Sopa Instantánea MARUCHAN Pollo...
#
#                                               categories  \
# 13681  [/Vinos, licores y cervezas/Espumantes/Cava/, ...
# 12271  [/Juguetes y Juegos/Juguetería/Otros Juguetes ...
# 6680   [/Decohogar/Menaje de Comedor/Sets de Vajilla/...
# 4119   [/Bebidas/Gaseosas/Gaseosas Personales/, /Bebi...
# 3572   [/Abarrotes/Comidas Instantáneas/Sopas/, /Abar...
#
#                                  categoriesIds  ...            ean  \
# 13681  [/1746/1753/1759/, /1746/1753/, /1746/]  ...  8413831125309
# 12271     [/999/1058/1386/, /999/1058/, /999/]  ...  2200202564708
# 6680            [/22/103/802/, /22/103/, /22/]  ...  7702484138202
# 4119             [/19/81/1146/, /19/81/, /19/]  ...
# 3572              [/17/60/259/, /17/60/, /17/]  ...    41789002915
#
#                                                 imageUrl Value IsAvailable  \
# 13681  https://vivanda.vteximg.com.br/arquivos/ids/40...  44.9        True
# 12271  https://vivanda.vteximg.com.br/arquivos/ids/35...   NaN       False
# 6680   https://vivanda.vteximg.com.br/arquivos/ids/21...  20.9        True
# 4119   https://vivanda.vteximg.com.br/arquivos/ids/42...  15.0        True
# 3572   https://vivanda.vteximg.com.br/arquivos/ids/46...   3.4        True
#
#       AvailableQuantity Price ListPrice PriceWithoutDiscount  \
# 13681               100  44.9      44.9                 44.9
# 12271                 0  89.9      89.9                 89.9
# 6680              99999  20.9      20.9                 20.9
# 4119                100  15.0      15.0                 15.0
# 3572                100   3.4       3.4                  3.4
#
#             PriceValidUntil              Created
# 13681  3000-01-02T00:00:00Z  2024-10-14 15:20:26
# 12271  3000-01-02T00:00:00Z  2024-10-14 15:20:26
# 6680   3000-01-02T00:00:00Z  2024-10-14 15:20:26
# 4119   3000-01-02T05:00:00Z  2024-10-14 15:20:26
# 3572   3000-01-02T00:00:00Z  2024-10-14 15:20:26
#
# [5 rows x 33 columns]

# %%
df[['productId', 'productName', 'brand', 'categoryId', 'link', 'Price', 'AvailableQuantity']].sample(n=8)
# Out:
#        productId                                    productName        brand  \
# 6607       41528        Set de Contenedores  VIVA HOME 5 Piezas    VIVA HOME
# 13719       8426   Vino SANTA JULIA Reserva Syrah Botella 750ml  SANTA JULIA
# 10227  100214270                    Coca y Muña SUNKA Caja 20un        SUNKA
# 6288       31904                     Escoba VIRUTEX Súper Dalia      VIRUTEX
# 2401   100544032           Chocolate Baileys MONTBLANC Caja 80g    MONTBLANC
# 9688   100086237      Hierba Luisa LA FIDELIA Radiante Caja10un   LA FIDELIA
# 7243   100543428  Televisor LG LED 50" UHD 4K ThinQ AI 50UR7300           LG
# 8478   100214821         Helado de Chocolate ZUBZERO Pote 500ml      ZUBZERO
#
#       categoryId                                               link   Price  \
# 6607        1225  https://www.vivanda.com.pe/set-de-contenedores...    29.9
# 13719       1775  https://www.vivanda.com.pe/vino-santa-julia-re...    42.9
# 10227       1294  https://www.vivanda.com.pe/coca-y-muna-sunka-c...     7.0
# 6288         391  https://www.vivanda.com.pe/escoba-virutex-supe...     0.0
# 2401        1100  https://www.vivanda.com.pe/chocolate-baileys-m...    18.5
# 9688        1294  https://www.vivanda.com.pe/hierba-luisa-la-fid...    30.9
# 7243         539  https://www.vivanda.com.pe/televisor-lg-led-50...  1399.0
# 8478         325  https://www.vivanda.com.pe/helado-de-chocolate...    16.0
#
#        AvailableQuantity
# 6607               99999
# 13719                 10
# 10227                  0
# 6288                   0
# 2401                 100
# 9688                 100
# 7243                 100
# 8478                  10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14285 entries, 0 to 14284
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   productId                  14285 non-null  object
#  1   productName                14285 non-null  object
#  2   brand                      14285 non-null  object
#  3   brandId                    14285 non-null  int64
#  4   brandImageUrl              0 non-null      object
#  5   categoryId                 14285 non-null  object
#  6   productTitle               14285 non-null  object
#  7   metaTagDescription         14285 non-null  object
#  8   categories                 14285 non-null  object
#  9   categoriesIds              14285 non-null  object
#  10  link                       14285 non-null  object
#  11  Vendido por                0 non-null      object
#  12  Descripción del producto   14285 non-null  object
#  13  Presentación               111 non-null    object
#  14  Presentación/Empaque       3207 non-null   object
#  15  Pack                       63 non-null     object
#  16  Porción Sugerida           1557 non-null   object
#  17  Azúcares Por Porción       1790 non-null   object
#  18  Carbohidratos Por Porción  1864 non-null   object
#  19  Descripción Nutricional    858 non-null    object
#  20  Grasas Por Porción         1421 non-null   object
#  21  Advertencias de consumo    1579 non-null   object
#  22  itemId                     14285 non-null  object
#  23  ean                        14285 non-null  object
#  24  imageUrl                   14285 non-null  object
#  25  Value                      9759 non-null   float64
#  26  IsAvailable                14285 non-null  bool
#  27  AvailableQuantity          14285 non-null  int64
#  28  Price                      14285 non-null  float64
#  29  ListPrice                  14285 non-null  float64
#  30  PriceWithoutDiscount       14285 non-null  float64
#  31  PriceValidUntil            12481 non-null  object
#  32  Created                    14285 non-null  object
# dtypes: bool(1), float64(4), int64(2), object(26)
# memory usage: 3.6+ MB

# %%
df['product_uri_json'] = df['productId'].apply(lambda x: f'https://www.vivanda.com.pe/api/catalog_system/pub/products/search?fq=productId:{x}')

# %%
df['product_uri_json'].sample(n=5)
# Out:
# 11424    https://www.vivanda.com.pe/api/catalog_system/...
# 13079    https://www.vivanda.com.pe/api/catalog_system/...
# 2901     https://www.vivanda.com.pe/api/catalog_system/...
# 7677     https://www.vivanda.com.pe/api/catalog_system/...
# 13168    https://www.vivanda.com.pe/api/catalog_system/...
# Name: product_uri_json, dtype: object

# %%
file_name_productos_csv = f'productos_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_productos_csv, index=False)

# %%
df.iloc[26955]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.iloc[26955]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
