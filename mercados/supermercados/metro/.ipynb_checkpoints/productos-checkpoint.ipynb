# %%
from datetime import datetime
import pytz

def fecha_hora_lima():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y%m%d-%H%M%S')

def fecha_hora_lima_db():
    lima_tz = pytz.timezone('America/Lima')
    lima_time = datetime.now(lima_tz)
    return lima_time.strftime('%Y-%m-%d %H:%M:%S')

fecha_hora_para_archivos = fecha_hora_lima()
fecha_hora_para_base_de_datos = fecha_hora_lima_db()

# %%
import pandas as pd
import requests
import json

# URL del JSON
url = 'https://www.metro.pe/api/catalog_system/pub/category/tree/3'

# Solicitar el contenido JSON desde la URL
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    data = response.json()  # Convertir la respuesta en un objeto JSON
    file_name = f'categories_{fecha_hora_para_archivos}.json'
    
    # Guardar el JSON en un archivo
    with open(file_name, 'w') as file:
        json.dump(data, file, indent=4)

    print('El archivo JSON se ha guardado exitosamente.')
    with open(file_name, 'r') as file:
        data = json.load(file)
    print(len(data)) 
else:
    print(f'Error al obtener el JSON. Código de estado: {response.status_code}')
# Out:
# El archivo JSON se ha guardado exitosamente.
# 26

# %%
# file_path = 'metro_categories.json'
# 
# with open(file_path, 'r') as file:
#     data = json.load(file)
#     print(json.dumps(data, indent=4))

# %%
columns = ['id', 'name', 'hasChildren', 'url', 'NumChildren', 'Title', 'MetaTagDescription', 'parent_id']
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [id, name, hasChildren, url, NumChildren, Title, MetaTagDescription, parent_id]
# Index: []

# %%
for item in data:
  if item['hasChildren']:
    item['parent_id'] = ''
    item['NumChildren'] = len(item['children'])

    df.loc[len(df)] = item

    parent_id = item['id']

    for subitem in item['children']:
      subitem['parent_id'] = parent_id
      sub_parent_id = subitem['id']
      subitem['NumChildren'] = len(subitem['children'])

      df.loc[len(df)] = subitem

      if len(subitem['children']) > 0:
        for subsubitem in subitem['children']:
          subsubitem['parent_id'] = sub_parent_id
          subsubitem['NumChildren'] = len(subsubitem['children'])
          df.loc[len(df)] = subsubitem

# %%
df.query("id == 812")
# Out:
#     id                    name  hasChildren  \
# 4  812  Fresas y Otros Berries        False
#
#                                                  url  NumChildren  \
# 4  https://www.metro.pe/frutas-y-verduras/frutas/...            0
#
#                                                Title  \
# 4  Fresas y Otros Frutos Rojos - Arándanos, Moras...
#
#                                   MetaTagDescription parent_id
# 4  Descubre una variedad de fresas y frutos rojos...       801

# %%
file_name_categories_csv = f'metro_categories_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_categories_csv, index=False)

# %%
cats = df.query("parent_id == ''")['id'].to_list()
print(cats)
print(len(cats))
# Out:
# [800, 1200, 1400, 1700, 1800, 1900, 2000, 2100, 2200, 2301, 1000003, 1000069, 1000131, 1000143, 1000144, 1001074, 1001253, 1001327, 1001374, 1001402, 1001436, 1001467, 1001470, 1001701]
# 24

# %%
import time

products = []

for cat in cats:
    start = 0
    end = 49
    
    while True:
        time.sleep(1)
        url = f"https://www.metro.pe/api/catalog_system/pub/products/search?fq=C:{cat}&_from={start}&_to={end}&O=OrderByPriceDESC"
        
        response = requests.get(url)
        
        if response.status_code == 200 or response.status_code == 206:
            data = response.json()
            if not data:
                break
                 
            products.extend(data)
            start += 50
            end += 50
        else:
            break
    
    print(f"status_code = {response.status_code}")
    print(f"cat = {cat}, start = {start}, end = {end}")

 
file_name_productos_csv = f'productos_{fecha_hora_para_archivos}.json'

with open(file_name_productos_csv, 'w') as file:
    json.dump(products, file, indent=4)
# Out:
# status_code = 200
# cat = 800, start = 500, end = 549
# status_code = 200
# cat = 1200, start = 400, end = 449
# status_code = 500
# cat = 1400, start = 350, end = 399
# status_code = 500
# cat = 1700, start = 1300, end = 1349
# status_code = 200
# cat = 1800, start = 600, end = 649
# status_code = 500
# cat = 1900, start = 200, end = 249
# status_code = 500
# cat = 2000, start = 800, end = 849
# status_code = 200
# cat = 2100, start = 1350, end = 1399
# status_code = 500
# cat = 2200, start = 2300, end = 2349
# status_code = 200
# cat = 2301, start = 1900, end = 1949
# status_code = 200
# cat = 1000003, start = 400, end = 449
# status_code = 200
# cat = 1000069, start = 400, end = 449
# status_code = 500
# cat = 1000131, start = 950, end = 999
# status_code = 200
# cat = 1000143, start = 850, end = 899
# status_code = 200
# cat = 1000144, start = 300, end = 349
# status_code = 500
# cat = 1001074, start = 1450, end = 1499
# status_code = 500
# cat = 1001253, start = 850, end = 899
# status_code = 200
# cat = 1001327, start = 550, end = 599
# status_code = 200
# cat = 1001374, start = 450, end = 499
# status_code = 200
# cat = 1001402, start = 250, end = 299
# status_code = 200
# cat = 1001436, start = 900, end = 949
# status_code = 200
# cat = 1001467, start = 1200, end = 1249
# status_code = 200
# cat = 1001470, start = 500, end = 549
# status_code = 200
# cat = 1001701, start = 50, end = 99

# %%
print(len(products))
# Out:
# 18346

# %%
columns = ['productId', 'productName', 'brand', 'brandId', 'brandImageUrl','categoryId',
           'productTitle', 'metaTagDescription', 'categories', 'categoriesIds', 'link', 'Vendido por',
           'Descripción del producto', 'Presentación', 'Presentación/Empaque', 'Pack', 'Porción Sugerida',
           'Azúcares Por Porción', 'Carbohidratos Por Porción', 'Descripción Nutricional', 'Grasas Por Porción',
           'Advertencias de consumo', 'itemId', 'ean', 'imageUrl', 'Value', 'IsAvailable', 'AvailableQuantity',
           'Price', 'ListPrice', 'PriceWithoutDiscount', 'PriceValidUntil', 'Created']

df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [productId, productName, brand, brandId, brandImageUrl, categoryId, productTitle, metaTagDescription, categories, categoriesIds, link, Vendido por, Descripción del producto, Presentación, Presentación/Empaque, Pack, Porción Sugerida, Azúcares Por Porción, Carbohidratos Por Porción, Descripción Nutricional, Grasas Por Porción, Advertencias de consumo, itemId, ean, imageUrl, Value, IsAvailable, AvailableQuantity, Price, ListPrice, PriceWithoutDiscount, PriceValidUntil, Created]
# Index: []
#
# [0 rows x 33 columns]

# %%
for product in products:
  print(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'])
  print(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'])
  break
# Out:
# 260.0
# 2100-01-01T00:00:00Z
# 260.0
# 260.0

# %%
print(json.dumps(products[3099], indent=4))
# Out:
# {
#     "productId": "1031254",
#     "productName": "Detergente L\u00edquido MAS Color 3L",
#     "brand": "MAS Color",
#     "brandId": 2004494,
#     "brandImageUrl": null,
#     "linkText": "detergente-liquido-mas-color-3l-1012818",
#     "productReference": "1012818",
#     "productReferenceCode": "1012818",
#     "categoryId": "1000715",
#     "productTitle": "Detergente L\u00edquido MAS Color 3L",
#     "metaTagDescription": "\u00a1Encuentra aqu\u00ed los mejores productos de Detergente L\u00edquido de la marca MAS COLOR!",
#     "releaseDate": "2024-09-27T00:00:00Z",
#     "clusterHighlights": {
#         "323": "Todo Supermercado Metro IO",
#         "351": "Todo supermercado 2.0",
#         "1490": "Coleccion todo Metro",
#         "1917": "Coleccion todo Metro II",
#         "1953": "Todo supermercado 3",
#         "2020": "Todo supermercado 4.0",
#         "2143": "Coleccion cupon Claro",
#         "2145": "Coleccion cupon Claro diciembre",
#         "2528": "compra hoy recibe hoy",
#         "3402": "Todo supermercado 5.0",
#         "3405": "Todo supermercado 5.1",
#         "3501": "Todo Supermercado 6.1 Sin Licores",
#         "3524": "Delivery gratis TC febrero",
#         "3591": "Detergente en polvo Ariel 2.8KG",
#         "3885": "TCenco Metro ABNC 5.03 AL 31.03",
#         "3928": "Delivery Gratis ABC y ABNC",
#         "3956": "ABNC T CENCO DELIVERY CYBER",
#         "4249": "Todo Supermercado 7.0 Sin arroz-aceite-leches",
#         "4305": "Todo Supermercado Sin Leches-Aceite-Cerveza",
#         "4342": "Twopack ace limon",
#         "4522": "CUPON INFLUENCER CYBERWOW",
#         "4523": "COLECC INFLUENCER CYBERWOW",
#         "4645": "Metro Ahorro Miercoles Abarrotes",
#         "4732": "Delivery gratis CON TC en papeles desechables, det",
#         "4734": "deter mass",
#         "4738": "Cupon Metro No Comestible",
#         "4958": "TC METRO ABARROTES NUEVO",
#         "5053": "TC DELIVERY MAYO"
#     },
#     "productClusters": {
#         "323": "Todo Supermercado Metro IO",
#         "351": "Todo supermercado 2.0",
#         "1490": "Coleccion todo Metro",
#         "1917": "Coleccion todo Metro II",
#         "1953": "Todo supermercado 3",
#         "2020": "Todo supermercado 4.0",
#         "2143": "Coleccion cupon Claro",
#         "2145": "Coleccion cupon Claro diciembre",
#         "2528": "compra hoy recibe hoy",
#         "3402": "Todo supermercado 5.0",
#         "3405": "Todo supermercado 5.1",
#         "3501": "Todo Supermercado 6.1 Sin Licores",
#         "3524": "Delivery gratis TC febrero",
#         "3591": "Detergente en polvo Ariel 2.8KG",
#         "3885": "TCenco Metro ABNC 5.03 AL 31.03",
#         "3928": "Delivery Gratis ABC y ABNC",
#         "3956": "ABNC T CENCO DELIVERY CYBER",
#         "4249": "Todo Supermercado 7.0 Sin arroz-aceite-leches",
#         "4305": "Todo Supermercado Sin Leches-Aceite-Cerveza",
#         "4342": "Twopack ace limon",
#         "4522": "CUPON INFLUENCER CYBERWOW",
#         "4523": "COLECC INFLUENCER CYBERWOW",
#         "4645": "Metro Ahorro Miercoles Abarrotes",
#         "4732": "Delivery gratis CON TC en papeles desechables, det",
#         "4734": "deter mass",
#         "4738": "Cupon Metro No Comestible",
#         "4958": "TC METRO ABARROTES NUEVO",
#         "5053": "TC DELIVERY MAYO"
#     },
#     "searchableClusters": {
#         "323": "Todo Supermercado Metro IO",
#         "351": "Todo supermercado 2.0",
#         "1490": "Coleccion todo Metro",
#         "1917": "Coleccion todo Metro II",
#         "1953": "Todo supermercado 3",
#         "2020": "Todo supermercado 4.0",
#         "2143": "Coleccion cupon Claro",
#         "2145": "Coleccion cupon Claro diciembre",
#         "2528": "compra hoy recibe hoy",
#         "3402": "Todo supermercado 5.0",
#         "3405": "Todo supermercado 5.1",
#         "3501": "Todo Supermercado 6.1 Sin Licores",
#         "3524": "Delivery gratis TC febrero",
#         "3591": "Detergente en polvo Ariel 2.8KG",
#         "3885": "TCenco Metro ABNC 5.03 AL 31.03",
#         "3928": "Delivery Gratis ABC y ABNC",
#         "3956": "ABNC T CENCO DELIVERY CYBER",
#         "4249": "Todo Supermercado 7.0 Sin arroz-aceite-leches",
#         "4305": "Todo Supermercado Sin Leches-Aceite-Cerveza",
#         "4342": "Twopack ace limon",
#         "4522": "CUPON INFLUENCER CYBERWOW",
#         "4523": "COLECC INFLUENCER CYBERWOW",
#         "4645": "Metro Ahorro Miercoles Abarrotes",
#         "4732": "Delivery gratis CON TC en papeles desechables, det",
#         "4734": "deter mass",
#         "4738": "Cupon Metro No Comestible",
#         "4958": "TC METRO ABARROTES NUEVO",
#         "5053": "TC DELIVERY MAYO"
#     },
#     "categories": [
#         "/Limpieza/Cuidado de Ropa/Detergente L\u00edquido/",
#         "/Limpieza/Cuidado de Ropa/",
#         "/Limpieza/"
#     ],
#     "categoriesIds": [
#         "/1900/1902/1000715/",
#         "/1900/1902/",
#         "/1900/"
#     ],
#     "link": "https://www.metro.pe/detergente-liquido-mas-color-3l-1012818/p",
#     "ProductData": [
#         "{\"allow_notes\":true,\"allow_substitute\":true,\"cart_limit\":\"9\",\"brandName\":\"MAS Color\",\"brandEcomId\":\"2004494\",\"measurement_unit\":\"un\",\"unit_multiplier\":1,\"measurement_unit_selector\":false}"
#     ],
#     "SkuData": [
#         "{\"39270225\":{\"ref_id\":\"1012818\",\"cart_limit\":9,\"allow_notes\":true,\"allow_substitute\":true,\"measurement_unit\":\"un\",\"unit_multiplier\":1,\"promotions\":[\"2063868\",\"2112409\",\"2182197\"],\"url_canonical\":null,\"measurement_unit_selector\":false,\"release_data\":{\"is_new\":false}}}"
#     ],
#     "Configuraciones": [
#         "ProductData",
#         "SkuData"
#     ],
#     "allSpecifications": [
#         "ProductData",
#         "SkuData"
#     ],
#     "allSpecificationsGroups": [
#         "Configuraciones"
#     ],
#     "description": "<li>Contiene 3 litros</li><li>Detergente l\u00edquido dise\u00f1ado para el cuidado y  renovaci\u00f3n de color</li><li>Cuida las fibras, evita pelusas y bolitas</li><li>Renueva los colores</li></li>M\u00e1s limpieza, m\u00e1s cuidado</li>",
#     "items": [
#         {
#             "itemId": "39270225",
#             "name": "Detergente L\u00edquido MAS Color 3L",
#             "nameComplete": "Detergente L\u00edquido MAS Color 3L",
#             "complementName": "",
#             "ean": "7500459000758",
#             "referenceId": [
#                 {
#                     "Key": "RefId",
#                     "Value": "1012818"
#                 }
#             ],
#             "measurementUnit": "un",
#             "unitMultiplier": 1.0,
#             "modalType": null,
#             "isKit": false,
#             "images": [
#                 {
#                     "imageId": "520559",
#                     "imageLabel": "1012818-01",
#                     "imageTag": "<img src=\"~/arquivos/ids/520559-#width#-#height#/Detergente-L-quido-MAS-Color-3L-1-257889.jpg?v=638483890126300000\" width=\"#width#\" height=\"#height#\" alt=\"Detergente-L-quido-MAS-Color-3L-1-257889\" id=\"\" />",
#                     "imageUrl": "https://metroio.vteximg.com.br/arquivos/ids/520559/Detergente-L-quido-MAS-Color-3L-1-257889.jpg?v=638483890126300000",
#                     "imageText": "Detergente-L-quido-MAS-Color-3L-1-257889",
#                     "imageLastModified": "2024-04-10T23:36:52.6300000Z"
#                 },
#                 {
#                     "imageId": "520406",
#                     "imageLabel": "1012818-02",
#                     "imageTag": "<img src=\"~/arquivos/ids/520406-#width#-#height#/Detergente-L-quido-MAS-Color-3L-2-257889.jpg?v=638483889657270000\" width=\"#width#\" height=\"#height#\" alt=\"Detergente-L-quido-MAS-Color-3L-2-257889\" id=\"\" />",
#                     "imageUrl": "https://metroio.vteximg.com.br/arquivos/ids/520406/Detergente-L-quido-MAS-Color-3L-2-257889.jpg?v=638483889657270000",
#                     "imageText": "Detergente-L-quido-MAS-Color-3L-2-257889",
#                     "imageLastModified": "2024-04-10T23:36:05.7270000Z"
#                 },
#                 {
#                     "imageId": "520410",
#                     "imageLabel": "1012818-03",
#                     "imageTag": "<img src=\"~/arquivos/ids/520410-#width#-#height#/Detergente-L-quido-MAS-Color-3L-3-257889.jpg?v=638483889671570000\" width=\"#width#\" height=\"#height#\" alt=\"Detergente-L-quido-MAS-Color-3L-3-257889\" id=\"\" />",
#                     "imageUrl": "https://metroio.vteximg.com.br/arquivos/ids/520410/Detergente-L-quido-MAS-Color-3L-3-257889.jpg?v=638483889671570000",
#                     "imageText": "Detergente-L-quido-MAS-Color-3L-3-257889",
#                     "imageLastModified": "2024-04-10T23:36:07.1570000Z"
#                 }
#             ],
#             "sellers": [
#                 {
#                     "sellerId": "1",
#                     "sellerName": "CENCOSUD RETAIL PERU S.A.",
#                     "addToCartLink": "https://www.metro.pe/checkout/cart/add?sku=39270225&qty=1&seller=1&sc=1&price=5950&cv=_&sc=1",
#                     "sellerDefault": true,
#                     "commertialOffer": {
#                         "DeliverySlaSamplesPerRegion": {
#                             "0": {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         },
#                         "Installments": [
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 19.83,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 3,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 9.91,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 6,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 7.43,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 8,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 6.61,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 9,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 4.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 12,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 3.3,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 18,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 2.47,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 24,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 1.65,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 36,
#                                 "PaymentSystemName": "American Express",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "American Express"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 19.83,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 3,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 9.91,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 6,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 8.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 7,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 7.43,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 8,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 6.61,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 9,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 5.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 10,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 5.4,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 11,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 4.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 12,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 4.57,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 13,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 4.25,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 14,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 3.3,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 18,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 2.47,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 24,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 1.65,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 36,
#                                 "PaymentSystemName": "Visa",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Visa"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 19.83,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 3,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 9.91,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 6,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 7.43,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 8,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 6.61,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 9,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 4.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 12,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 3.3,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 18,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 2.47,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 24,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 1.65,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 36,
#                                 "PaymentSystemName": "Diners",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Diners"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 19.83,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 3,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 9.91,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 6,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 8.5,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 7,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 7.43,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 8,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 6.61,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 9,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 5.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 10,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 5.4,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 11,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 4.95,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 12,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 4.57,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 13,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 4.25,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 14,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 3.3,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 18,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 2.47,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 24,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 1.65,
#                                 "InterestRate": null,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 36,
#                                 "PaymentSystemName": "Mastercard",
#                                 "PaymentSystemGroupName": "creditCardPaymentGroup",
#                                 "Name": "Mastercard"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Cash",
#                                 "PaymentSystemGroupName": "cashPaymentGroup",
#                                 "Name": "Cash \u00e0 vista"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "Pago Yape/Plin",
#                                 "PaymentSystemGroupName": "custom205PaymentGroupPaymentGroup",
#                                 "Name": "Pago Yape/Plin \u00e0 vista"
#                             },
#                             {
#                                 "Value": 59.5,
#                                 "InterestRate": 0.0,
#                                 "TotalValuePlusInterestRate": 59.5,
#                                 "NumberOfInstallments": 1,
#                                 "PaymentSystemName": "CardPromissory",
#                                 "PaymentSystemGroupName": "cardPromissoryPaymentGroup",
#                                 "Name": "CardPromissory \u00e0 vista"
#                             }
#                         ],
#                         "DiscountHighLight": [],
#                         "GiftSkuIds": [],
#                         "Teasers": [],
#                         "PromotionTeasers": [],
#                         "BuyTogether": [],
#                         "ItemMetadataAttachment": [],
#                         "Price": 59.5,
#                         "ListPrice": 65.0,
#                         "PriceWithoutDiscount": 59.5,
#                         "FullSellingPrice": 59.5,
#                         "RewardValue": 0.0,
#                         "PriceValidUntil": "2100-01-01T04:59:59Z",
#                         "AvailableQuantity": 100,
#                         "IsAvailable": true,
#                         "Tax": 0.0,
#                         "DeliverySlaSamples": [
#                             {
#                                 "DeliverySlaPerTypes": [],
#                                 "Region": null
#                             }
#                         ],
#                         "GetInfoErrorMessage": null,
#                         "CacheVersionUsedToCallCheckout": "_",
#                         "PaymentOptions": {
#                             "installmentOptions": [
#                                 {
#                                     "paymentSystem": "1",
#                                     "bin": null,
#                                     "paymentName": "American Express",
#                                     "paymentGroupName": "creditCardPaymentGroup",
#                                     "value": 5950,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 5950,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 1,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 5950,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 3,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 1983,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 3,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 1983,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 6,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 991,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 6,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 991,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 8,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 743,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 8,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 743,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 9,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 661,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 9,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 661,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 12,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 495,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 12,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 495,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 18,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 330,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 18,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 330,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 24,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 247,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 24,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 247,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 36,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 165,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 36,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 165,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "2",
#                                     "bin": null,
#                                     "paymentName": "Visa",
#                                     "paymentGroupName": "creditCardPaymentGroup",
#                                     "value": 5950,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 5950,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 1,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 5950,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 3,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 1983,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 3,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 1983,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 6,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 991,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 6,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 991,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 7,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 850,
# ...
#                                             "count": 13,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 457,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 13,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 457,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 14,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 425,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 14,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 425,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 18,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 330,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 18,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 330,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 24,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 247,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 24,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 247,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "count": 36,
#                                             "hasInterestRate": null,
#                                             "interestRate": null,
#                                             "value": 165,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 36,
#                                                     "hasInterestRate": null,
#                                                     "interestRate": null,
#                                                     "value": 165,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "47",
#                                     "bin": null,
#                                     "paymentName": "Cash",
#                                     "paymentGroupName": "cashPaymentGroup",
#                                     "value": 5950,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 5950,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 5950,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "205",
#                                     "bin": null,
#                                     "paymentName": "Pago Yape/Plin",
#                                     "paymentGroupName": "custom205PaymentGroupPaymentGroup",
#                                     "value": 5950,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 5950,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 5950,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "paymentSystem": "601",
#                                     "bin": null,
#                                     "paymentName": "CardPromissory",
#                                     "paymentGroupName": "cardPromissoryPaymentGroup",
#                                     "value": 5950,
#                                     "installments": [
#                                         {
#                                             "count": 1,
#                                             "hasInterestRate": false,
#                                             "interestRate": 0,
#                                             "value": 5950,
#                                             "total": 5950,
#                                             "sellerMerchantInstallments": [
#                                                 {
#                                                     "id": "METROIO",
#                                                     "count": 1,
#                                                     "hasInterestRate": false,
#                                                     "interestRate": 0,
#                                                     "value": 5950,
#                                                     "total": 5950
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "paymentSystems": [
#                                 {
#                                     "id": 47,
#                                     "name": "Cash",
#                                     "groupName": "cashPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "47",
#                                     "template": "cashPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:53:37.3288107Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 601,
#                                     "name": "CardPromissory",
#                                     "groupName": "cardPromissoryPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "601",
#                                     "template": "cardPromissoryPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:53:37.3288108Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 3,
#                                     "name": "Diners",
#                                     "groupName": "creditCardPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "3",
#                                     "template": "creditCardPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:52:37.3288109Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 1,
#                                     "name": "American Express",
#                                     "groupName": "creditCardPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "1",
#                                     "template": "creditCardPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:52:37.328811Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 2,
#                                     "name": "Visa",
#                                     "groupName": "creditCardPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "2",
#                                     "template": "creditCardPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:52:37.3288112Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 4,
#                                     "name": "Mastercard",
#                                     "groupName": "creditCardPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "4",
#                                     "template": "creditCardPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": false,
#                                     "description": null,
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:52:37.3288114Z",
#                                     "availablePayments": null
#                                 },
#                                 {
#                                     "id": 205,
#                                     "name": "Pago Yape/Plin",
#                                     "groupName": "custom205PaymentGroupPaymentGroup",
#                                     "validator": null,
#                                     "stringId": "205",
#                                     "template": "custom205PaymentGroupPaymentGroup-template",
#                                     "requiresDocument": false,
#                                     "isCustom": true,
#                                     "description": "",
#                                     "requiresAuthentication": false,
#                                     "dueDate": "2024-11-20T17:53:37.3288115Z",
#                                     "availablePayments": null
#                                 }
#                             ],
#                             "payments": [],
#                             "giftCards": [],
#                             "giftCardMessages": [],
#                             "availableAccounts": [],
#                             "availableTokens": []
#                         }
#                     }
#                 }
#             ],
#             "Videos": [],
#             "estimatedDateArrival": null
#         }
#     ]
# }

# %%
# print(json.dumps(products, indent=4))

# %%
def print_value(value, key):
    if value:
        print(f"{key} = {value}")
    else:
        print(f"{key} = None")

# %%
from bs4 import BeautifulSoup

def clean_html(html_code):
    if html_code is None:
        return ''
    if isinstance(html_code, list):
        html_code = ' '.join(html_code)
    soup = BeautifulSoup(html_code, 'html.parser')
    return soup.get_text()

# %%
def get_product_data(product, fecha_db):
    product['Created'] = fecha_db
    new_product = {}
    new_product['productId'] = product.get('productId')
    new_product['productName'] = product.get('productName')
    new_product['brand'] = product.get('brand')
    new_product['brandId'] = product.get('brandId')
    new_product['brandImageUrl'] = product.get('brandImageUrl')
    new_product['categoryId'] = product.get('categoryId')
    new_product['productTitle'] = product.get('productTitle')
    new_product['metaTagDescription'] = product.get('metaTagDescription')
    new_product['categories'] = product.get('categories')
    new_product['categoriesIds'] = product.get('categoriesIds')
    new_product['link'] = product.get('link')
    new_product['Vendido por'] = product.get('Vendido por')
    new_product['Descripción del producto'] = clean_html(product.get('Descripción del producto'))
    new_product['Presentación'] = product.get('Presentación')
    new_product['Presentación/Empaque'] = product.get('Presentación/Empaque')
    new_product['Pack'] = product.get('Pack')
    new_product['Porción Sugerida'] = product.get('Porción Sugerida')
    new_product['Azúcares Por Porción'] = product.get('Azúcares Por Porción')
    new_product['Carbohidratos Por Porción'] = product.get('Carbohidratos Por Porción')
    new_product['Descripción Nutricional'] = product.get('Descripción Nutricional')
    new_product['Grasas Por Porción'] = product.get('Grasas Por Porción')
    new_product['Advertencias de consumo'] = product.get('Advertencias de consumo')
    
    if product['items']:
        new_product['itemId'] = product['items'][0].get('itemId', None)
        new_product['ean'] = product['items'][0].get('ean', None)
        if product['items'][0]['images']:
            new_product['imageUrl'] = product['items'][0]['images'][0].get('imageUrl', None)
            if product['items'][0]['sellers']:
                commertial_offer = product['items'][0]['sellers'][0].get('commertialOffer', {})
                if commertial_offer.get('Installments'):
                    new_product['Value'] = commertial_offer['Installments'][0].get('Value', None)
                new_product['IsAvailable'] = commertial_offer.get('IsAvailable', None)
                new_product['AvailableQuantity'] = commertial_offer.get('AvailableQuantity', None)
                new_product['Price'] = commertial_offer.get('Price', None)
                new_product['ListPrice'] = commertial_offer.get('ListPrice', None)
                new_product['PriceWithoutDiscount'] = commertial_offer.get('PriceWithoutDiscount', None)
                new_product['PriceValidUntil'] = commertial_offer.get('PriceValidUntil', None)

    new_product['Created'] = product['Created']
    
    return new_product

# %%
# Para validar que los datos se están extrayendo correctamente

i = 0
for product in products:
    i += 1
    product['Created'] = fecha_hora_lima_db()
    print_value(product.get('productId'), 'productId')
    print_value(product.get('productName'), 'productName')
    print_value(product.get('brand'), 'brand')
    print_value(product.get('brandId'), 'brandId')
    print_value(product.get('brandImageUrl'), 'brandImageUrl')
    print_value(product.get('categoryId'), 'categoryId')
    print_value(product.get('productTitle'), 'productTitle')
    print_value(product.get('metaTagDescription'), 'metaTagDescription')
    print_value(product.get('categories'), 'categories')
    print_value(product.get('categoriesIds'), 'categoriesIds')
    print_value(product.get('link'), 'link')
    print_value(product.get('Vendido por'), 'Vendido por')
    print_value(clean_html(product.get('Descripción del producto')), 'Descripción del producto')
    print_value(product.get('Presentación'), 'Presentación')
    print_value(product.get('Presentación/Empaque'), 'Presentación/Empaque')
    print_value(product.get('Pack'), 'Pack')
    print_value(product.get('Porción Sugerida'), 'Porción Sugerida')
    print_value(product.get('Azúcares Por Porción'), 'Azúcares Por Porción')
    print_value(product.get('Carbohidratos Por Porción'), 'Carbohidratos Por Porción')
    print_value(product.get('Descripción Nutricional'), 'Descripción Nutricional')
    print_value(product.get('Grasas Por Porción'), 'Grasas Por Porción')
    print_value(product.get('Advertencias de consumo'), 'Advertencias de consumo')
    print_value(product['items'][0]['itemId'], 'itemId')
    print_value(product['items'][0]['ean'], 'ean')
    print_value(product['items'][0]['images'][0]['imageUrl'], 'imageUrl')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Installments'][0]['Value'], 'Value')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['IsAvailable'], 'IsAvailable')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['AvailableQuantity'], 'AvailableQuantity')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['Price'], 'Price')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['ListPrice'], 'ListPrice')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceWithoutDiscount'], 'PriceWithoutDiscount')
    print_value(product['items'][0]['sellers'][0]['commertialOffer']['PriceValidUntil'], 'PriceValidUntil')
    print_value(product['Created'], 'Created')
    
    if i == 3:
        break

print(len(products))
# Out:
# productId = 939171
# productName = Fresa Deshidratada Natifrut x kg
# brand = Genérico
# brandId = 9619
# brandImageUrl = None
# categoryId = 1001317
# productTitle = Fresa Deshidratada Natifrut x kg
# metaTagDescription = ¡Encuentra aquí los mejores productos de Frutos Secos a Granel de la marca GENÉRICO!
# categories = ['/Frutas y Verduras/Frutas/Frutos Secos/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/800/801/1001317/', '/800/801/', '/800/']
# link = https://www.metro.pe/fresa-deshidratada-natifrut-x-kg-771046/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 39179919
# ean = 22392
# imageUrl = https://metroio.vteximg.com.br/arquivos/ids/518047/771046-01-56790.jpg?v=638472009850800000
# Value = 260.0
# IsAvailable = True
# AvailableQuantity = 100
# Price = 260.0
# ListPrice = 260.0
# PriceWithoutDiscount = 260.0
# PriceValidUntil = 2100-01-01T00:00:00Z
# Created = 2024-11-13 13:21:42
# productId = 1024766
# productName = Pecanas Saladas x kg
# brand = Genérico
# brandId = 9619
# brandImageUrl = None
# categoryId = 1001317
# productTitle = Pecanas Saladas x kg
# metaTagDescription = ¡Encuentra aquí los mejores productos de Frutos Secos a Granel de la marca GENÉRICO!
# categories = ['/Frutas y Verduras/Frutas/Frutos Secos/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/800/801/1001317/', '/800/801/', '/800/']
# link = https://www.metro.pe/pecanas-saladas-x-kg-1003135/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 39263704
# ean = 2571540000006
# imageUrl = https://metroio.vteximg.com.br/arquivos/ids/546047/Pecanas-Saladas-x-kg-1-245601.jpg?v=638629149800400000
# Value = 189.0
# IsAvailable = True
# AvailableQuantity = 1
# Price = 189.0
# ListPrice = 189.0
# PriceWithoutDiscount = 189.0
# PriceValidUntil = 2100-01-01T00:00:00Z
# Created = 2024-11-13 13:21:42
# productId = 10476
# productName = Pecana Pelada x kg
# brand = Genérico
# brandId = 9619
# brandImageUrl = None
# categoryId = 1001317
# productTitle = Pecana Pelada x kg
# metaTagDescription = ¡Encuentra aquí la mejor variedad de Frutos Secos a Granel de la marca .!
# categories = ['/Frutas y Verduras/Frutas/Frutos Secos/', '/Frutas y Verduras/Frutas/', '/Frutas y Verduras/']
# categoriesIds = ['/800/801/1001317/', '/800/801/', '/800/']
# link = https://www.metro.pe/pecana-pelada-x-kg-4711/p
# Vendido por = None
# Descripción del producto = None
# Presentación = None
# Presentación/Empaque = None
# Pack = None
# Porción Sugerida = None
# Azúcares Por Porción = None
# Carbohidratos Por Porción = None
# Descripción Nutricional = None
# Grasas Por Porción = None
# Advertencias de consumo = None
# itemId = 10488
# ean = 34067
# imageUrl = https://metroio.vteximg.com.br/arquivos/ids/246608/Pecana-Pelada-x-kg-1-32330.jpg?v=638173943024670000
# Value = 149.0
# IsAvailable = True
# AvailableQuantity = 99999
# Price = 149.0
# ListPrice = 149.0
# PriceWithoutDiscount = 149.0
# PriceValidUntil = 2100-01-01T00:00:00Z
# Created = 2024-11-13 13:21:42
# 18346

# %%
i=0
for product in products:
    i+=1
    if i % 100 == 0:
        print("Iteración #: ",i)
    new_product = get_product_data(product, fecha_hora_para_base_de_datos)
    df.loc[len(df)] = new_product
# Out:
# Iteración #:  100
# Iteración #:  200
# Iteración #:  300
# Iteración #:  400
# Iteración #:  500
# Iteración #:  600
# Iteración #:  700
# Iteración #:  800
# Iteración #:  900
# Iteración #:  1000
# Iteración #:  1100
# Iteración #:  1200
# Iteración #:  1300
# Iteración #:  1400
# Iteración #:  1500
# Iteración #:  1600
# Iteración #:  1700
# Iteración #:  1800
# Iteración #:  1900
# Iteración #:  2000
# Iteración #:  2100
# Iteración #:  2200
# Iteración #:  2300
# Iteración #:  2400
# Iteración #:  2500
# Iteración #:  2600
# Iteración #:  2700
# Iteración #:  2800
# Iteración #:  2900
# Iteración #:  3000
# Iteración #:  3100
# Iteración #:  3200
# Iteración #:  3300
# Iteración #:  3400
# Iteración #:  3500
# Iteración #:  3600
# Iteración #:  3700
# Iteración #:  3800
# Iteración #:  3900
# Iteración #:  4000
# Iteración #:  4100
# Iteración #:  4200
# Iteración #:  4300
# Iteración #:  4400
# Iteración #:  4500
# Iteración #:  4600
# Iteración #:  4700
# Iteración #:  4800
# Iteración #:  4900
# Iteración #:  5000
# Iteración #:  5100
# Iteración #:  5200
# Iteración #:  5300
# Iteración #:  5400
# Iteración #:  5500
# Iteración #:  5600
# Iteración #:  5700
# Iteración #:  5800
# Iteración #:  5900
# Iteración #:  6000
# Iteración #:  6100
# Iteración #:  6200
# Iteración #:  6300
# Iteración #:  6400
# Iteración #:  6500
# Iteración #:  6600
# Iteración #:  6700
# Iteración #:  6800
# Iteración #:  6900
# Iteración #:  7000
# Iteración #:  7100
# Iteración #:  7200
# Iteración #:  7300
# Iteración #:  7400
# Iteración #:  7500
# Iteración #:  7600
# Iteración #:  7700
# Iteración #:  7800
# Iteración #:  7900
# Iteración #:  8000
# Iteración #:  8100
# Iteración #:  8200
# Iteración #:  8300
# Iteración #:  8400
# Iteración #:  8500
# Iteración #:  8600
# Iteración #:  8700
# Iteración #:  8800
# Iteración #:  8900
# Iteración #:  9000
# Iteración #:  9100
# Iteración #:  9200
# Iteración #:  9300
# Iteración #:  9400
# Iteración #:  9500
# Iteración #:  9600
# Iteración #:  9700
# Iteración #:  9800
# Iteración #:  9900
# Iteración #:  10000
# Iteración #:  10100
# Iteración #:  10200
# Iteración #:  10300
# Iteración #:  10400
# Iteración #:  10500
# Iteración #:  10600
# Iteración #:  10700
# Iteración #:  10800
# Iteración #:  10900
# Iteración #:  11000
# Iteración #:  11100
# Iteración #:  11200
# Iteración #:  11300
# Iteración #:  11400
# Iteración #:  11500
# Iteración #:  11600
# Iteración #:  11700
# Iteración #:  11800
# Iteración #:  11900
# Iteración #:  12000
# Iteración #:  12100
# Iteración #:  12200
# Iteración #:  12300
# Iteración #:  12400
# Iteración #:  12500
# Iteración #:  12600
# Iteración #:  12700
# Iteración #:  12800
# Iteración #:  12900
# Iteración #:  13000
# Iteración #:  13100
# Iteración #:  13200
# Iteración #:  13300
# Iteración #:  13400
# Iteración #:  13500
# Iteración #:  13600
# Iteración #:  13700
# Iteración #:  13800
# Iteración #:  13900
# Iteración #:  14000
# Iteración #:  14100
# Iteración #:  14200
# Iteración #:  14300
# Iteración #:  14400
# Iteración #:  14500
# Iteración #:  14600
# Iteración #:  14700
# Iteración #:  14800
# Iteración #:  14900
# Iteración #:  15000
# Iteración #:  15100
# Iteración #:  15200
# Iteración #:  15300
# Iteración #:  15400
# Iteración #:  15500
# Iteración #:  15600
# Iteración #:  15700
# Iteración #:  15800
# Iteración #:  15900
# Iteración #:  16000
# Iteración #:  16100
# Iteración #:  16200
# Iteración #:  16300
# Iteración #:  16400
# Iteración #:  16500
# Iteración #:  16600
# Iteración #:  16700
# Iteración #:  16800
# Iteración #:  16900
# Iteración #:  17000
# Iteración #:  17100
# Iteración #:  17200
# Iteración #:  17300
# Iteración #:  17400
# Iteración #:  17500
# Iteración #:  17600
# Iteración #:  17700
# Iteración #:  17800
# Iteración #:  17900
# Iteración #:  18000
# Iteración #:  18100
# Iteración #:  18200
# Iteración #:  18300

# %%
df.sample(n=5)
# Out:
#       productId                                        productName  \
# 1208    1043392                                   Pack Abarrotes 2
# 13985   1022108  Mantequilla de Frutos Secos Choco Almendras Th...
# 8784    1026741               Blist Boligrafo Artesco Tops 505 3un
# 11321    570216  Almohada de Lactancia Doble Maternelle Celeste...
# 15555    573796                              Pan de Yema Metro 8un
#
#                     brand  brandId brandImageUrl categoryId  \
# 1208                Metro  2000891          None    1000671
# 13985  The Butter Factory  2002533          None    1001269
# 8784              Artesco     3889          None    1000875
# 11321          Maternelle  2000468          None    1000729
# 15555               Metro  2000891          None    1001655
#
#                                             productTitle  \
# 1208                                    Pack Abarrotes 2
# 13985                                               None
# 8784                Blist Boligrafo Artesco Tops 505 3un
# 11321  Almohada de Lactancia Doble Maternelle Celeste...
# 15555                              Pan de Yema Metro 8un
#
#                                       metaTagDescription  \
# 1208   ¡Encuentra aquí los mejores productos de Aceit...
# 13985                                               None
# 8784   ¡Encuentra aquí la mejor variedad en productos...
# 11321  ¡Encuentra aquí los mejores productos de Mater...
# 15555  ¡Encuentra aquí los mejores productos de Panes...
#
#                                               categories  \
# 1208   [/Abarrotes/Aceites/Aceites Vegetales/, /Abarr...
# 13985  [/Desayuno/Mermeladas y Mieles/Mantequilla de ...
# 8784   [/Libros y Librería/Útiles Escolares y Oficina...
# 11321  [/Niños y Bebés/Mundo Bebé/Maternidad/, /Niños...
# 15555  [/Panadería y Pastelería/La Panadería/Panes Em...
#
#                                            categoriesIds  ...            ean  \
# 1208          [/1700/1709/1000671/, /1700/1709/, /1700/]  ...  2050044348956
# 13985  [/1001253/1001266/1001269/, /1001253/1001266/,...  ...  7757505000068
# 8784    [/2301/1000873/1000875/, /2301/1000873/, /2301/]  ...  7750082136168
# 11321  [/1000143/1000169/1000729/, /1000143/1000169/,...  ...  7758927006942
# 15555  [/1001374/1001375/1001655/, /1001374/1001375/,...  ...  2050043808178
#
#                                                 imageUrl   Value IsAvailable  \
# 1208   https://metroio.vteximg.com.br/arquivos/ids/53...   73.29        True
# 13985  https://metroio.vteximg.com.br/arquivos/ids/48...   31.50        True
# 8784   https://metroio.vteximg.com.br/arquivos/ids/50...    6.20        True
# 11321  https://metroio.vteximg.com.br/arquivos/ids/53...  179.90        True
# 15555  https://metroio.vteximg.com.br/arquivos/ids/52...    6.59        True
#
#       AvailableQuantity   Price ListPrice PriceWithoutDiscount  \
# 1208              99999   73.29     73.29                73.29
# 13985               100   31.50     34.90                31.50
# 8784                 10    6.20      6.20                 6.20
# 11321                10  179.90    179.90               179.90
# 15555                10    6.59      6.59                 6.59
#
#             PriceValidUntil              Created
# 1208   2100-01-01T00:00:00Z  2024-11-13 13:02:45
# 13985  2100-01-01T00:00:00Z  2024-11-13 13:02:45
# 8784   2100-01-01T00:00:00Z  2024-11-13 13:02:45
# 11321  2025-09-02T00:00:00Z  2024-11-13 13:02:45
# 15555  2100-01-01T00:00:00Z  2024-11-13 13:02:45
#
# [5 rows x 33 columns]

# %%
df[['productId', 'productName', 'brand', 'categoryId', 'link', 'Price', 'AvailableQuantity']].sample(n=8)
# Out:
#       productId                                        productName  \
# 2779    1060489           REHIDRATANTE SUEROX 630ML , FRUTOS ROJOS
# 10850    576758  Decohome Centro de Entretenimiento Turquía Rob...
# 18074   1031468          Cartel Krea Santa Auto Viaje Navidad 2024
# 12274    573584                Hp Cartucho de Tinta HP667 Tricolor
# 211       39964                               Tuna Roja Metro x kg
# 1210        436  Aceite de Oliva La Española Extra Virgen Botel...
# 4215    1023417  Gin Tanqueray Dark Berry Royale Botella 700ml ...
# 6687    1028198          Body Lotion Beauty Care Love Summer 250ml
#
#              brand categoryId  \
# 2779        Suerox       1808
# 10850     Decohome       1315
# 18074         Krea    1001494
# 12274           HP    1000028
# 211       Genérico        813
# 1210   La Española       1733
# 4215     Tanqueray       2107
# 6687   Beauty Care    1001211
#
#                                                     link    Price  \
# 2779   https://www.metro.pe/rehidratante-suerox-630ml...     6.50
# 10850  https://www.metro.pe/decohome-centro-de-entret...  1288.56
# 18074  https://www.metro.pe/cartel-krea-santa-auto-vi...     7.20
# 12274  https://www.metro.pe/hp-cartucho-de-tinta-hp66...    50.00
# 211        https://www.metro.pe/tuna-roja-metro-x-kg-2/p     7.99
# 1210   https://www.metro.pe/aceite-de-oliva-la-espano...    72.50
# 4215   https://www.metro.pe/gin-tanqueray-dark-berry-...    89.90
# 6687   https://www.metro.pe/body-lotion-beauty-care-l...    19.90
#
#        AvailableQuantity
# 2779                 100
# 10850                100
# 18074                100
# 12274                100
# 211                  100
# 1210                 100
# 4215                  10
# 6687                 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18346 entries, 0 to 18345
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   productId                  18346 non-null  object
#  1   productName                18346 non-null  object
#  2   brand                      18346 non-null  object
#  3   brandId                    18346 non-null  int64
#  4   brandImageUrl              0 non-null      object
#  5   categoryId                 18346 non-null  object
#  6   productTitle               14520 non-null  object
#  7   metaTagDescription         11838 non-null  object
#  8   categories                 18346 non-null  object
#  9   categoriesIds              18346 non-null  object
#  10  link                       18346 non-null  object
#  11  Vendido por                0 non-null      object
#  12  Descripción del producto   18346 non-null  object
#  13  Presentación               72 non-null     object
#  14  Presentación/Empaque       0 non-null      object
#  15  Pack                       0 non-null      object
#  16  Porción Sugerida           0 non-null      object
#  17  Azúcares Por Porción       0 non-null      object
#  18  Carbohidratos Por Porción  0 non-null      object
#  19  Descripción Nutricional    0 non-null      object
#  20  Grasas Por Porción         0 non-null      object
#  21  Advertencias de consumo    0 non-null      object
#  22  itemId                     18346 non-null  object
#  23  ean                        18346 non-null  object
#  24  imageUrl                   18346 non-null  object
#  25  Value                      18271 non-null  float64
#  26  IsAvailable                18346 non-null  bool
#  27  AvailableQuantity          18346 non-null  int64
#  28  Price                      18346 non-null  float64
#  29  ListPrice                  18346 non-null  float64
#  30  PriceWithoutDiscount       18346 non-null  float64
#  31  PriceValidUntil            18319 non-null  object
#  32  Created                    18346 non-null  object
# dtypes: bool(1), float64(4), int64(2), object(26)
# memory usage: 4.6+ MB

# %%
df['product_uri_json'] = df['productId'].apply(lambda x: f'https://www.metro.pe/api/catalog_system/pub/products/search?fq=productId:{x}')

# %%
df['product_uri_json'].sample(n=5)
# Out:
# 10035    https://www.metro.pe/api/catalog_system/pub/pr...
# 17005    https://www.metro.pe/api/catalog_system/pub/pr...
# 9414     https://www.metro.pe/api/catalog_system/pub/pr...
# 14468    https://www.metro.pe/api/catalog_system/pub/pr...
# 10307    https://www.metro.pe/api/catalog_system/pub/pr...
# Name: product_uri_json, dtype: object

# %%
file_name_productos_csv = f'productos_{fecha_hora_para_archivos}.csv'
df.to_csv(file_name_productos_csv, index=False)

# %%
df.iloc[18000]
# Out:
# productId                                                              1026717
# productName                  Bolsa de Regalo Benji Santa Reno Pingüino en T...
# brand                                                                    Benji
# brandId                                                                   3807
# brandImageUrl                                                             None
# categoryId                                                             1001493
# productTitle                 Bolsa de Regalo Benji Santa Reno Pingüino en T...
# metaTagDescription           ¡Encuentra aquí la mejor variedad en productos...
# categories                   [/Navidad/Navidad Textil/Bolsas Navideñas/, /N...
# categoriesIds                [/1001470/1001476/1001493/, /1001470/1001476/,...
# link                         https://www.metro.pe/bolsa-de-regalo-benji-san...
# Vendido por                                                               None
# Descripción del producto
# Presentación                                                              None
# Presentación/Empaque                                                      None
# Pack                                                                      None
# Porción Sugerida                                                          None
# Azúcares Por Porción                                                      None
# Carbohidratos Por Porción                                                 None
# Descripción Nutricional                                                   None
# Grasas Por Porción                                                        None
# Advertencias de consumo                                                   None
# itemId                                                                39265750
# ean                                                              2050044218716
# imageUrl                     https://metroio.vteximg.com.br/arquivos/ids/50...
# Value                                                                    11.99
# IsAvailable                                                               True
# AvailableQuantity                                                          100
# Price                                                                    11.99
# ListPrice                                                                11.99
# PriceWithoutDiscount                                                     11.99
# PriceValidUntil                                           2100-01-01T00:00:00Z
# Created                                                    2024-11-13 13:02:45
# product_uri_json             https://www.metro.pe/api/catalog_system/pub/pr...
# Name: 18000, dtype: object
